# %%
import requests
from bs4  import BeautifulSoup
import pandas as pd
import numpy as np

from time import sleep
from random import randint
from warnings import warn
from time import time

# %% [markdown]
# ## Restaurant

# %%
#  1 webscraping Hotels
# Monitoring of the loop
start_time = time()
request = 0

# Dictionary for storing web content
soup_r = {}
for start_num in range(0, 240, 10):

    # Make a request
    url = f" https://www.yelp.com/search?find_desc=Restaurants&find_loc=london&start={start_num}"
    response = requests.get(url)

    # Pause the loop
    sleep(randint(8,15))
    print(response)
    page = BeautifulSoup(response.content, 'html.parser')
    soup_r[start_num] = page


    # Monitor the requests
    request += 1
    elapsed_time = time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))
    #clear_output(wait = True)

    # Throw a warning if request wasn't successful
    if response.status_code != 200:
        warn('Request: {}; Status code: {}'.format(request, response.status_code))
# Out:
# <Response [200]>
# Request:1; Frequency: 0.05968387229129174 requests/s
# <Response [200]>
# Request:2; Frequency: 0.05991291373535699 requests/s
# <Response [200]>
# Request:3; Frequency: 0.06394885730729385 requests/s
# <Response [200]>
# Request:4; Frequency: 0.06242277411251014 requests/s
# <Response [200]>
# Request:5; Frequency: 0.061191991963975845 requests/s
# <Response [200]>
# Request:6; Frequency: 0.06512634865258049 requests/s
# <Response [200]>
# Request:7; Frequency: 0.06573423802833395 requests/s
# <Response [200]>
# Request:8; Frequency: 0.0656955793096753 requests/s
# <Response [200]>
# Request:9; Frequency: 0.06765730202870142 requests/s
# <Response [200]>
# Request:10; Frequency: 0.06714933925804802 requests/s
# <Response [200]>
# Request:11; Frequency: 0.06768801406919 requests/s
# <Response [200]>
# Request:12; Frequency: 0.06929924172314302 requests/s
# <Response [200]>
# Request:13; Frequency: 0.07038740765767416 requests/s
# <Response [200]>
# Request:14; Frequency: 0.07174449420160275 requests/s
# <Response [200]>
# Request:15; Frequency: 0.07088412034211572 requests/s
# <Response [200]>
# Request:16; Frequency: 0.0713301340406466 requests/s
# <Response [200]>
# Request:17; Frequency: 0.07063040974502771 requests/s
# <Response [200]>
# Request:18; Frequency: 0.07164195223288156 requests/s
# <Response [200]>
# Request:19; Frequency: 0.07206560468423334 requests/s
# <Response [200]>
# Request:20; Frequency: 0.0718682177652282 requests/s
# <Response [200]>
# Request:21; Frequency: 0.07164050199335005 requests/s
# <Response [200]>
# Request:22; Frequency: 0.07151361276936259 requests/s
# <Response [200]>
# Request:23; Frequency: 0.07061853452267969 requests/s
# <Response [200]>
# Request:24; Frequency: 0.07046539323378014 requests/s

# %%
resto_soup = pd.DataFrame([soup_r]).squeeze()

# %%
# save to csv
pd.DataFrame([soup_r]).to_csv('restaurant_soup.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ritth\code\Strive\Streamlit_project\fulldata_for_london_page2.ipynb Cell 4' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Streamlit_project/fulldata_for_london_page2.ipynb#ch0000003?line=0'>1</a> # save to csv
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Streamlit_project/fulldata_for_london_page2.ipynb#ch0000003?line=1'>2</a> pd.DataFrame([soup_r]).to_csv('restaurant_soup.csv')
#
# NameError: name 'soup_r' is not defined

# %% [markdown]
# ## Page 2

# %%
# details about each business
request = 0
start_time = time()

soup_r2 = pd.DataFrame() 
ser = pd.read_csv('C:\\Users\\ritth\\code\\Strive\\Streamlit_project\\restaurant_soup.csv').drop(columns='Unnamed: 0').squeeze()
for row in ser:
    page = BeautifulSoup(row, 'html.parser')
    a_tags = page.select('.css-1egxyvc .css-1m051bw')
    for tag in a_tags:
        # print(tag)
        name = tag.text
        link = tag['href']
        url = f'https://wwww.yelp.com{link}'
        response = requests.get(url)

        # Pause the loop
        sleep(randint(8,15))
        print(response)
        page = BeautifulSoup(response.content, 'html.parser')
        soup_r2[name] = [page]

        # Monitor the requests
        request += 1
        elapsed_time = time() - start_time
        print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))

        # Throw a warning if request wasn't successful
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(request, response.status_code))
# Out:
# <Response [200]>
# Request:1; Frequency: 0.05888521492121255 requests/s
# <Response [200]>
# Request:2; Frequency: 0.07016803189138442 requests/s
# <Response [200]>
# Request:3; Frequency: 0.07292247216594157 requests/s
# <Response [200]>
# Request:4; Frequency: 0.0714785343654331 requests/s
# <Response [200]>
# Request:5; Frequency: 0.06705329087623337 requests/s
# <Response [200]>
# Request:6; Frequency: 0.06812461287794827 requests/s
# <Response [200]>
# Request:7; Frequency: 0.06732651932612611 requests/s
# <Response [200]>
# Request:8; Frequency: 0.06598561839996588 requests/s
# <Response [200]>
# Request:9; Frequency: 0.06449001814591201 requests/s
# <Response [200]>
# Request:10; Frequency: 0.06536538979609322 requests/s
# <Response [200]>
# Request:11; Frequency: 0.06465923210959047 requests/s
# <Response [200]>
# Request:12; Frequency: 0.06405797409889619 requests/s
# <Response [200]>
# Request:13; Frequency: 0.06434280103566677 requests/s
# <Response [200]>
# Request:14; Frequency: 0.06352914679718408 requests/s
# <Response [200]>
# Request:15; Frequency: 0.06386586168041518 requests/s
# <Response [200]>
# Request:16; Frequency: 0.06401514432982762 requests/s
# <Response [200]>
# Request:17; Frequency: 0.06400120343485283 requests/s
# <Response [200]>
# Request:18; Frequency: 0.06456332890256715 requests/s
# <Response [200]>
# Request:19; Frequency: 0.06400810814057459 requests/s
# <Response [200]>
# Request:20; Frequency: 0.06367580546416439 requests/s
# <Response [200]>
# Request:21; Frequency: 0.06431196670284345 requests/s
# <Response [200]>
# Request:22; Frequency: 0.06420327243784091 requests/s
# <Response [200]>
# Request:23; Frequency: 0.06378898173288039 requests/s
# <Response [200]>
# Request:24; Frequency: 0.06359373557119458 requests/s
# <Response [200]>
# Request:25; Frequency: 0.06322426116026726 requests/s
# <Response [200]>
# Request:26; Frequency: 0.0630364198004836 requests/s
# <Response [200]>
# Request:27; Frequency: 0.0626073058467524 requests/s
# <Response [200]>
# Request:28; Frequency: 0.06252873053261598 requests/s
# <Response [200]>
# Request:29; Frequency: 0.06245376361972516 requests/s
# <Response [200]>
# Request:30; Frequency: 0.06306340489690067 requests/s
# <Response [200]>
# Request:31; Frequency: 0.06299240702244484 requests/s
# <Response [200]>
# Request:32; Frequency: 0.06307439316337157 requests/s
# <Response [200]>
# Request:33; Frequency: 0.06335847226574381 requests/s
# <Response [200]>
# Request:34; Frequency: 0.06331204947983549 requests/s
# <Response [200]>
# Request:35; Frequency: 0.06332583143058193 requests/s
# <Response [200]>
# Request:36; Frequency: 0.06364805785453165 requests/s
# <Response [200]>
# Request:37; Frequency: 0.06345365179870333 requests/s
# <Response [200]>
# Request:38; Frequency: 0.06350267947943365 requests/s
# <Response [200]>
# Request:39; Frequency: 0.0632705459105424 requests/s
# <Response [200]>
# Request:40; Frequency: 0.06355466167468103 requests/s
# <Response [200]>
# Request:41; Frequency: 0.06381608382369137 requests/s
# <Response [200]>
# Request:42; Frequency: 0.06406718941841817 requests/s
# <Response [200]>
# Request:43; Frequency: 0.06388055188583981 requests/s
# <Response [200]>
# Request:44; Frequency: 0.06380897194776511 requests/s
# <Response [200]>
# Request:45; Frequency: 0.06352201416104454 requests/s
# <Response [200]>
# Request:46; Frequency: 0.06341661464895777 requests/s
# <Response [200]>
# Request:47; Frequency: 0.06338746609520143 requests/s
# <Response [200]>
# Request:48; Frequency: 0.06346534872935006 requests/s
# <Response [200]>
# Request:49; Frequency: 0.06330317144515471 requests/s
# <Response [200]>
# Request:50; Frequency: 0.06358696457268966 requests/s
# <Response [200]>
# Request:51; Frequency: 0.0635517208239653 requests/s
# <Response [200]>
# Request:52; Frequency: 0.06372168123350663 requests/s
# <Response [200]>
# Request:53; Frequency: 0.06386969114378596 requests/s
# <Response [200]>
# Request:54; Frequency: 0.06405530920477506 requests/s
# <Response [200]>
# Request:55; Frequency: 0.0638176143897152 requests/s
# <Response [200]>
# Request:56; Frequency: 0.06380678178903829 requests/s
# <Response [200]>
# Request:57; Frequency: 0.06329807772255654 requests/s
# <Response [200]>
# Request:58; Frequency: 0.06324707387946307 requests/s
# <Response [200]>
# Request:59; Frequency: 0.06323844131506291 requests/s
# <Response [200]>
# Request:60; Frequency: 0.06311398351002152 requests/s
# <Response [200]>
# Request:61; Frequency: 0.06299951249819573 requests/s
# <Response [200]>
# Request:62; Frequency: 0.06319226575029635 requests/s
# <Response [200]>
# Request:63; Frequency: 0.06345987027240395 requests/s
# <Response [200]>
# Request:64; Frequency: 0.06332974894349898 requests/s
# <Response [200]>
# Request:65; Frequency: 0.06336457731915167 requests/s
# <Response [200]>
# Request:66; Frequency: 0.06325428968993249 requests/s
# <Response [200]>
# Request:67; Frequency: 0.06315961981980832 requests/s
# <Response [200]>
# Request:68; Frequency: 0.06335565027812938 requests/s
# <Response [200]>
# Request:69; Frequency: 0.0635501943210281 requests/s
# <Response [200]>
# Request:70; Frequency: 0.06347108304285051 requests/s
# <Response [200]>
# Request:71; Frequency: 0.06349849500407458 requests/s
# <Response [200]>
# Request:72; Frequency: 0.06350643637508724 requests/s
# <Response [200]>
# Request:73; Frequency: 0.06341131191750451 requests/s
# <Response [200]>
# Request:74; Frequency: 0.06358557105140827 requests/s
# <Response [200]>
# Request:75; Frequency: 0.06365389707370099 requests/s
# <Response [200]>
# Request:76; Frequency: 0.06363479974251318 requests/s
# <Response [200]>
# Request:77; Frequency: 0.06363566828569688 requests/s
# <Response [200]>
# Request:78; Frequency: 0.0635692908475209 requests/s
# <Response [200]>
# Request:79; Frequency: 0.06343994510461307 requests/s
# <Response [200]>
# Request:80; Frequency: 0.0633100322376613 requests/s
# <Response [200]>
# Request:81; Frequency: 0.0633797532102779 requests/s
# <Response [200]>
# Request:82; Frequency: 0.06317110214839299 requests/s
# <Response [200]>
# Request:83; Frequency: 0.0633419314725569 requests/s
# <Response [200]>
# Request:84; Frequency: 0.06321406594163334 requests/s
# <Response [200]>
# Request:85; Frequency: 0.06332235202852758 requests/s
# <Response [200]>
# Request:86; Frequency: 0.06323146453846704 requests/s
# <Response [200]>
# Request:87; Frequency: 0.06339067192634787 requests/s
# <Response [200]>
# Request:88; Frequency: 0.06331715069119256 requests/s
# <Response [200]>
# Request:89; Frequency: 0.06328917235876387 requests/s
# <Response [200]>
# Request:90; Frequency: 0.06320050303927374 requests/s
# <Response [200]>
# Request:91; Frequency: 0.0631156314064968 requests/s
# <Response [200]>
# Request:92; Frequency: 0.06321156189054086 requests/s
# <Response [200]>
# Request:93; Frequency: 0.06312311876403408 requests/s
# <Response [200]>
# Request:94; Frequency: 0.0630354035627556 requests/s
# <Response [200]>
# Request:95; Frequency: 0.06290847631991345 requests/s
# <Response [200]>
# Request:96; Frequency: 0.06277219758936971 requests/s
# <Response [200]>
# Request:97; Frequency: 0.06293294015557424 requests/s
# <Response [200]>
# Request:98; Frequency: 0.06296197633671992 requests/s
# <Response [200]>
# Request:99; Frequency: 0.06304259763406878 requests/s
# <Response [200]>
# Request:100; Frequency: 0.06301737919685889 requests/s
# <Response [200]>
# Request:101; Frequency: 0.0630541016267644 requests/s
# <Response [200]>
# Request:102; Frequency: 0.06294010231529801 requests/s
# <Response [200]>
# Request:103; Frequency: 0.06287861245293101 requests/s
# <Response [200]>
# Request:104; Frequency: 0.06295812085094374 requests/s
# <Response [200]>
# Request:105; Frequency: 0.06291865953716919 requests/s
# <Response [200]>
# Request:106; Frequency: 0.06272409825788781 requests/s
# <Response [200]>
# Request:107; Frequency: 0.06258960003484217 requests/s
# <Response [200]>
# Request:108; Frequency: 0.06260586220597572 requests/s
# <Response [200]>
# Request:109; Frequency: 0.06251603933669453 requests/s
# <Response [200]>
# Request:110; Frequency: 0.06260000589974572 requests/s
# <Response [200]>
# Request:111; Frequency: 0.06251633600012317 requests/s
# <Response [200]>
# Request:112; Frequency: 0.06249919507325463 requests/s
# <Response [200]>
# Request:113; Frequency: 0.06245471512388718 requests/s
# <Response [200]>
# Request:114; Frequency: 0.06247654320325629 requests/s
# <Response [200]>
# Request:115; Frequency: 0.06244184129304995 requests/s
# <Response [200]>
# Request:116; Frequency: 0.06252510142483085 requests/s
# <Response [200]>
# Request:117; Frequency: 0.0626520118046624 requests/s
# <Response [200]>
# Request:118; Frequency: 0.06272890329033094 requests/s
# <Response [200]>
# Request:119; Frequency: 0.06291437152123154 requests/s
# <Response [200]>
# Request:120; Frequency: 0.06296438925421256 requests/s
# <Response [200]>
# Request:121; Frequency: 0.06294156696235043 requests/s
# <Response [200]>
# Request:122; Frequency: 0.06306245098964322 requests/s
# <Response [200]>
# Request:123; Frequency: 0.0631206121733958 requests/s
# <Response [200]>
# Request:124; Frequency: 0.06302490785624368 requests/s
# <Response [200]>
# Request:125; Frequency: 0.06304781758732025 requests/s
# <Response [200]>
# Request:126; Frequency: 0.06298502216159782 requests/s
# <Response [200]>
# Request:127; Frequency: 0.06288735191346452 requests/s
# <Response [200]>
# Request:128; Frequency: 0.06295408979024006 requests/s
# <Response [200]>
# Request:129; Frequency: 0.06304555039984477 requests/s
# <Response [200]>
# Request:130; Frequency: 0.06299257733914368 requests/s
# <Response [200]>
# Request:131; Frequency: 0.06304338615421724 requests/s
# <Response [200]>
# Request:132; Frequency: 0.06316405131303925 requests/s
# <Response [200]>
# Request:133; Frequency: 0.06320349443264459 requests/s
# <Response [200]>
# Request:134; Frequency: 0.0633295013462861 requests/s
# <Response [200]>
# Request:135; Frequency: 0.0633892883602528 requests/s
# <Response [200]>
# Request:136; Frequency: 0.06350578952166892 requests/s
# <Response [200]>
# Request:137; Frequency: 0.06348193978776304 requests/s
# <Response [200]>
# Request:138; Frequency: 0.0636009528623303 requests/s
# <Response [200]>
# Request:139; Frequency: 0.06359216448323575 requests/s
# <Response [200]>
# Request:140; Frequency: 0.06352988337758932 requests/s
# <Response [200]>
# Request:141; Frequency: 0.0635105817773522 requests/s
# <Response [200]>
# Request:142; Frequency: 0.06353359651040323 requests/s
# <Response [200]>
# Request:143; Frequency: 0.06344424570099517 requests/s
# <Response [200]>
# Request:144; Frequency: 0.06346853826711753 requests/s
# <Response [200]>
# Request:145; Frequency: 0.06355569957720417 requests/s
# <Response [200]>
# Request:146; Frequency: 0.06344027137672538 requests/s
# <Response [200]>
# Request:147; Frequency: 0.06353917830692113 requests/s
# <Response [200]>
# Request:148; Frequency: 0.06349102943145267 requests/s
# <Response [200]>
# Request:149; Frequency: 0.06360700544713245 requests/s
# <Response [200]>
# Request:150; Frequency: 0.06355256925064973 requests/s
# <Response [200]>
# Request:151; Frequency: 0.06358061310027732 requests/s
# <Response [200]>
# Request:152; Frequency: 0.06348269946928849 requests/s
# <Response [200]>
# Request:153; Frequency: 0.063430561191393 requests/s
# <Response [200]>
# Request:154; Frequency: 0.06335445330761436 requests/s
# <Response [200]>
# Request:155; Frequency: 0.0634331905207573 requests/s
# <Response [200]>
# Request:156; Frequency: 0.06346372064886624 requests/s
# <Response [200]>
# Request:157; Frequency: 0.06353981953486926 requests/s
# <Response [200]>
# Request:158; Frequency: 0.06358009126716443 requests/s
# <Response [200]>
# Request:159; Frequency: 0.06366954986429497 requests/s
# <Response [200]>
# Request:160; Frequency: 0.06358595693204527 requests/s
# <Response [200]>
# Request:161; Frequency: 0.063535960280747 requests/s
# <Response [200]>
# Request:162; Frequency: 0.063604305251063 requests/s
# <Response [200]>
# Request:163; Frequency: 0.06362777122935735 requests/s
# <Response [200]>
# Request:164; Frequency: 0.06369157892829445 requests/s
# <Response [200]>
# Request:165; Frequency: 0.06366177358484014 requests/s
# <Response [200]>
# Request:166; Frequency: 0.06366517950015863 requests/s
# <Response [200]>
# Request:167; Frequency: 0.06374296406095584 requests/s
# <Response [200]>
# Request:168; Frequency: 0.06371069145695439 requests/s
# <Response [200]>
# Request:169; Frequency: 0.06370579382833279 requests/s
# <Response [200]>
# Request:170; Frequency: 0.0636522107972223 requests/s
# <Response [200]>
# Request:171; Frequency: 0.06358674402743554 requests/s
# <Response [200]>
# Request:172; Frequency: 0.06359345567774928 requests/s
# <Response [200]>
# Request:173; Frequency: 0.06357273196295227 requests/s
# <Response [200]>
# Request:174; Frequency: 0.06363092281491062 requests/s
# <Response [200]>
# Request:175; Frequency: 0.06371546405306967 requests/s
# <Response [200]>
# Request:176; Frequency: 0.06377710993402848 requests/s
# <Response [200]>
# Request:177; Frequency: 0.06373848983275511 requests/s
# <Response [200]>
# Request:178; Frequency: 0.06377819379920681 requests/s
# <Response [200]>
# Request:179; Frequency: 0.06381074713094852 requests/s
# <Response [200]>
# Request:180; Frequency: 0.06376239749958124 requests/s
# <Response [200]>
# Request:181; Frequency: 0.06370479274307003 requests/s
# <Response [200]>
# Request:182; Frequency: 0.06364280517534576 requests/s
# <Response [200]>
# Request:183; Frequency: 0.0636886648003232 requests/s
# <Response [200]>
# Request:184; Frequency: 0.06362053139854705 requests/s
# <Response [200]>
# Request:185; Frequency: 0.06360726895249984 requests/s
# <Response [200]>
# Request:186; Frequency: 0.0636922213691739 requests/s
# <Response [200]>
# Request:187; Frequency: 0.06361948339047754 requests/s
# <Response [200]>
# Request:188; Frequency: 0.06366248014180483 requests/s
# <Response [200]>
# Request:189; Frequency: 0.06371970736443958 requests/s
# <Response [200]>
# Request:190; Frequency: 0.06369822967273439 requests/s
# <Response [200]>
# Request:191; Frequency: 0.06375428860895672 requests/s
# <Response [200]>
# Request:192; Frequency: 0.06369234430213605 requests/s
# <Response [200]>
# Request:193; Frequency: 0.06365990880226972 requests/s
# <Response [200]>
# Request:194; Frequency: 0.06368606267038948 requests/s
# <Response [200]>
# Request:195; Frequency: 0.06358530753783724 requests/s
# <Response [200]>
# Request:196; Frequency: 0.06353070159903262 requests/s
# <Response [200]>
# Request:197; Frequency: 0.06350055467597317 requests/s
# <Response [200]>
# Request:198; Frequency: 0.0634775661652866 requests/s
# <Response [200]>
# Request:199; Frequency: 0.06344850080721656 requests/s
# <Response [200]>
# Request:200; Frequency: 0.0633786621513627 requests/s
# <Response [200]>
# Request:201; Frequency: 0.06338451907698008 requests/s
# <Response [200]>
# Request:202; Frequency: 0.06337168914161828 requests/s
# <Response [200]>
# Request:203; Frequency: 0.06345031986201967 requests/s
# <Response [200]>
# Request:204; Frequency: 0.06352569322777274 requests/s
# <Response [200]>
# Request:205; Frequency: 0.063513602694958 requests/s
# <Response [200]>
# Request:206; Frequency: 0.06347105097256094 requests/s
# <Response [200]>
# Request:207; Frequency: 0.06351624720511592 requests/s
# <Response [200]>
# Request:208; Frequency: 0.06348946781284301 requests/s
# <Response [200]>
# Request:209; Frequency: 0.06355114631524483 requests/s
# <Response [200]>
# Request:210; Frequency: 0.0636032213348745 requests/s
# <Response [200]>
# Request:211; Frequency: 0.06363717931963184 requests/s
# <Response [200]>
# Request:212; Frequency: 0.06357710079854172 requests/s
# <Response [200]>
# Request:213; Frequency: 0.06355685267616895 requests/s
# <Response [200]>
# Request:214; Frequency: 0.06353441711815401 requests/s
# <Response [200]>
# Request:215; Frequency: 0.06347873735065569 requests/s
# <Response [200]>
# Request:216; Frequency: 0.06343850459647113 requests/s
# <Response [200]>
# Request:217; Frequency: 0.06352080958814385 requests/s
# <Response [200]>
# Request:218; Frequency: 0.06350906065197698 requests/s
# <Response [200]>
# Request:219; Frequency: 0.06352535934099163 requests/s
# <Response [200]>
# Request:220; Frequency: 0.06352995039277877 requests/s
# <Response [200]>
# Request:221; Frequency: 0.06351907832424501 requests/s
# <Response [200]>
# Request:222; Frequency: 0.06354313277394275 requests/s
# <Response [200]>
# Request:223; Frequency: 0.06353018273791648 requests/s
# <Response [200]>
# Request:224; Frequency: 0.06353224738692345 requests/s
# <Response [200]>
# Request:225; Frequency: 0.06356903094904905 requests/s
# <Response [200]>
# Request:226; Frequency: 0.0636421177218688 requests/s
# <Response [200]>
# Request:227; Frequency: 0.06373011733378794 requests/s
# <Response [200]>
# Request:228; Frequency: 0.063755743889292 requests/s
# <Response [200]>
# Request:229; Frequency: 0.06374002310250926 requests/s
# <Response [200]>
# Request:230; Frequency: 0.06371400503474847 requests/s
# <Response [200]>
# Request:231; Frequency: 0.06373455483540519 requests/s
# <Response [200]>
# Request:232; Frequency: 0.06370690828323296 requests/s
# <Response [200]>
# Request:233; Frequency: 0.06373754109333038 requests/s
# <Response [200]>
# Request:234; Frequency: 0.06381005661952666 requests/s
# <Response [200]>
# Request:235; Frequency: 0.06379962774066146 requests/s
# <Response [200]>
# Request:236; Frequency: 0.0638520482780801 requests/s
# <Response [200]>
# Request:237; Frequency: 0.06378417975278104 requests/s
# <Response [200]>
# Request:238; Frequency: 0.06386138772931049 requests/s
# <Response [200]>
# Request:239; Frequency: 0.06380827761308684 requests/s
# <Response [200]>
# Request:240; Frequency: 0.06380036956263797 requests/s

# %%
# page2 store in csv, for reuse
soup_r2.to_csv('restaurant_soup2.csv')

# %%
resto_soup2 = pd.read_csv('C:\\Users\\ritth\\code\\Strive\\Streamlit_project\\restaurant_soup2.csv').drop(columns='Unnamed: 0').squeeze()

# %% [markdown]
# ### Name

# %%
name = []
for row in resto_soup:  
    result = row.select('.css-1egxyvc .css-1m051bw') 
    for tag in result:
        #print(tag.text)
        name.append(tag.text)

# %%
# pd.Series(name).value_counts()

# %% [markdown]
# ### Ratings

# %%
rating = []
container_class = 'container__09f24__mpR8_ hoverable__09f24__wQ_on margin-t3__09f24__riq4X margin-b3__09f24__l9v5d padding-t3__09f24__TMrIW padding-r3__09f24__eaF7p padding-b3__09f24__S8R2d padding-l3__09f24__IOjKY border--top__09f24__exYYb border--right__09f24__X7Tln border--bottom__09f24___mg5X border--left__09f24__DMOkM border-color--default__09f24__NPAKY'
for row in resto_soup:
    result = row.find_all(class_ = container_class)

    for tag in result:
        header_text = tag.div.div.div.nextSibling.div
        rat = header_text.select_one('.overflow--hidden__09f24___ayzG')
        if rat is not None:
            rating.append(rat['aria-label'].split()[0])
        else:
            rating.append(np.nan)

# %%
# test
# for n, rat in zip(name, rating):
#     print(n, rat)

# %% [markdown]
# ### Reviews

# %%
reviews = []
container_class = 'container__09f24__mpR8_ hoverable__09f24__wQ_on margin-t3__09f24__riq4X margin-b3__09f24__l9v5d padding-t3__09f24__TMrIW padding-r3__09f24__eaF7p padding-b3__09f24__S8R2d padding-l3__09f24__IOjKY border--top__09f24__exYYb border--right__09f24__X7Tln border--bottom__09f24___mg5X border--left__09f24__DMOkM border-color--default__09f24__NPAKY'
for row in resto_soup:
    result = row.find_all(class_ = container_class)

    for tag in result:
        header_text = tag.div.div.div.nextSibling.div
        rev = header_text.select_one('.reviewCount__09f24__tnBk4')
        if rev is not None:
            reviews.append(rev.text)
        else:
            reviews.append(np.nan)

# %%
# test
# for n, rev in zip(name, reviews):
#     print(n, rev)

# %% [markdown]
# ### Price

# %%
price_range = []
container_class = 'container__09f24__mpR8_ hoverable__09f24__wQ_on margin-t3__09f24__riq4X margin-b3__09f24__l9v5d padding-t3__09f24__TMrIW padding-r3__09f24__eaF7p padding-b3__09f24__S8R2d padding-l3__09f24__IOjKY border--top__09f24__exYYb border--right__09f24__X7Tln border--bottom__09f24___mg5X border--left__09f24__DMOkM border-color--default__09f24__NPAKY'
for row in resto_soup:
    result = row.find_all(class_ = container_class)

    for tag in result:
        header_text = tag.div.div.div.nextSibling.div
        price = header_text.select_one('.css-1s7bx9e')
        if price is not None:
            price_range.append(price.text)
        else:
            price_range.append(np.nan)

# %%
# test
# for n, price in zip(name, price_range):
#     print(n, price)

# %% [markdown]
# ### Photos

# %%
nb_photos = []
photo_header_class = 'photo-header-content-container__09f24__jDLBB border-color--default__09f24__NPAKY'
for row in resto_soup2:
    soup = BeautifulSoup(row, 'html.parser')
    photo_header = soup.find(class_ = photo_header_class)
    
    if photo_header is not None:
        nb_photos.append(  pd.Series(photo_header.text).str.extract(r'See (\d+) photos').squeeze()  )
    else:
        nb_photos.append(np.nan)

# %%
# df numbers of photo
for name, photo in zip(resto_soup2.index, nb_photos):
    print(name, photo)
# Out:
# Restaurant Gordon Ramsay 888
# The Mayfair Chippy 529
# Dishoom 1054
# The Fat Bear 287
# Duck & Waffle 2079
# Flat Iron 412
# The Queens Arms 134
# Padella 482
# Sketch 2746
# Honey & Co 203
# Duck & Waffle Local 328
# Hawksmoor Seven Dials 346
# Abeno 261
# Barrafina 267
# The Victoria 306
# The Ivy 188
# Lanzhou Noodle Bar 389
# Circolo Popolare 75
# The Breakfast Club 675
# Granger & Co 377
# The Ledbury 683
# BAO - Soho 698
# Belgo Centraal 260
# Ffiona’s Restaurant 418
# Jinjuu 303
# Ye Olde Cheshire Cheese 391
# Burger & Lobster 464
# Mestizo 128
# Gordon Ramsay Street Pizza 34
# Ottolenghi nan
# Yauatcha 942
# The Palomar Restaurant 277
# The Grazing Goat Marylebone 291
# Carmen Bar De Tapas 5
# Brasserie Zédel 351
# The Golden Chippy 108
# Drunch Regent’s Park 21
# Rules 283
# Fuckoffee 85
# Ngon Ngon 107
# Naru 105
# Mother Mash 587
# Arabesque nan
# Holborn Dining Room 168
# Haidilao Hot Pot 22
# Savoir Faire 159
# NOPI 532
# Shoryu Ramen 636
# London House by Gordon Ramsay 75
# Maggie Jones’s 112
# Hide 160
# HOOK 225
# Bocca Di Lupo 199
# Cecconi’s Mayfair 102
# Da Mario Restaurant nan
# Frenchie Covent Garden 118
# Texas Joe’s 64
# Piccolino 39
# Wahaca 251
# Bibimbap 169
# Sushi Tetsu 114
# The Alchemist 191
# Rocca 60
# St John Bar and Restaurant 422
# The English Rose Cafe and Tea Shop 350
# Kanada-Ya 299
# Busaba Soho 210
# The Rum Kitchen 156
# The Barge House 55
# The Narrow by Gordon Ramsay 106
# Frog By Adam Handling 78
# Andrew Edmunds 22
# Erebuni Restaurant 22
# Eggslut 57
# Market Halls Victoria 37
# Soho Joe 35
# Dinner by Heston Blumenthal 1023
# Chiltern Firehouse 355
# The Oystermen Seafood Bar & Kitchen 41
# Maria Sabina 52
# Silk Road 50
# Social Eating House 242
# Mar I Terra nan
# Zeitgeist 17
# Hammer & Tongs 29
# Goodman 92
# The Anchor and Hope 78
# Flour & Grape 60
# Kintan Japanese BBQ 171
# Ramo Ramen nan
# Kazu 37
# Where the Pancakes are 126
# Ma Po 17
# Tito’s 14
# Thai Square 18
# 39 Steps Coffee 17
# Berners Tavern 329
# Baltic Bar and Restaurant 39
# Hawksmoor 330
# Yasmeen Restaurant 57
# Lobos Meat and Tapas 138
# Sexy Fish 262
# The Wilmington 57
# Tokyo Sukiyaki-Tei 18
# Dominique Ansel Treehouse 23
# New Mayflower 101
# Hoppers 399
# Scully 21
# Gloria 78
# Paladar 33
# Pieminister 105
# Warisan Cafe 11
# Tayyabs 347
# Cacio & Pepe 17
# The Princess Victoria 43
# Scott’s 89
# The Pig & Goose at the George on the Strand 24
# Homeslice Neal’s Yard 209
# Xi’An BiangBiang Noodles 56
# Bradleys Restaurant 7
# Absurd Bird Soho 40
# Apollo Restaurant Taverna 17
# Orsini 62
# Liman Kitchen 20
# Casa do Frango 28
# Core by Clare Smyth 190
# River View Chinese Restaurant nan
# The Table 521
# The Wolseley 836
# Wok to Walk - Oxford St 91
# Waxy O’Connor’s 94
# The Harwood Arms 282
# Laksamania 41
# Negril 28
# Wright Brothers 183
# The Ninth London 102
# Emilia’s Crafted Pasta - Aldgate 20
# Dotori nan
# The George Inn 145
# The Lobster Pot 17
# Kazan 81
# Annabel’s 23
# Polo 24 Hour Bar 177
# Lahpet nan
# VQ Euston 22
# Korean Bbq and Vegan 27
# Oriental Dragon Restaurant 5
# Balaio Brazilian Grill nan
# Phat Phuc Noodle Bar 96
# Rumours nan
# Costa Azul 6
# Kerbisher & Malt 88
# Tokyo Diner 176
# Scalini Restaurant 69
# Maroush II 99
# The Book Club 79
# Eat Aroi Thai 22
# Bierschenke 38
# José 120
# The Old School Yard 44
# Dumpling Shack 27
# The Real Greek - Soho 66
# The Lion & Unicorn 20
# Al Balad 42
# BAO 262
# Andina 228
# Milk 67
# Terrace Grill and Bar 26
# Otto Restaurant nan
# Yatri Indian Restaurant 20
# CASK Pub and Kitchen 68
# Sabor 50
# Mamak Don 35
# Istanbul Cafe Bistro 35
# Romulo Cafe 70
# The Windmill 99
# Steak & Co 126
# The Barbary 232
# L’ETO 76
# Misato 132
# Honest Burgers Meard St - Soho 259
# German Doner Kebab 5
# Oblix At The Shard 367
# Brawn 84
# Ella Canta 41
# The Orangery 508
# Cereal Killer Cafe 335
# Sweet Chick 25
# The Swan 124
# Domo 94 nan
# Albertini Restaurant 95
# 10 Greek Street 87
# Flor 5
# Polpetto 38
# Nando’s 101

# %% [markdown]
# ### Location

# %%
location = [] 
for row in resto_soup2:
    soup = BeautifulSoup(row, 'html.parser')
    result = soup.select('address .raw__09f24__T4Ezm')

    adress_elements = []
    for tag in result:
            adress_elements.append(tag.text)
    location.append( '--'.join(adress_elements) )

# %%
location
# Out:
# ['68 Royal Hospital Road--London SW3 4HP--United Kingdom',
#  '14 North Audley Street--London W1K 6WE--United Kingdom',
#  '22 Kingly Street--London W1B 5QP--United Kingdom',
#  '61 Carter Lane--London EC4V 5DY--United Kingdom',
#  '110 Bishopsgate--40th Floor--London EC2N 4AY--United Kingdom',
#  '17-18 Henrietta Street--Covent Garden WC2E 8QH--United Kingdom',
#  '11 Warwick Way--Pimlico--London SW1V 1QT--United Kingdom',
#  '6 Southwark Street--London SE1 1TQ--United Kingdom',
#  '9 Conduit Street--Mayfair--London W1S 2XG--United Kingdom',
#  '25a Warren Street--London W1T 5LZ--United Kingdom',
#  "52 Haymarket--St James's Market--London SW1Y 4RP--United Kingdom",
#  '11 Langley Street--London WC2H 9JG--United Kingdom',
#  '47 Museum Street--London WC1A 1LY--United Kingdom',
#  '43 Drury Lane--Covent Garden--London WC2B 5RT--United Kingdom',
#  '10a Strathearn Place--Paddington W2 2NH--United Kingdom',
#  '1 - 5 West Street--London WC2H 9NQ--United Kingdom',
#  '33 Cranbourne Street--London WC2H 7AD--United Kingdom',
#  '40-41 Rathbone Place--London W1T 1HX--United Kingdom',
#  "33 D'Arblay Street--London W1F 8EU--United Kingdom",
#  '175 Westbourne Grove--London W11 2SB--United Kingdom',
#  '127 Ledbury Road--London W11 2AQ--United Kingdom',
#  '53 Lexington Street--London W1F 9AS--United Kingdom',
#  '50 Earlham Street--London WC2H 9LJ--United Kingdom',
#  '51 Kensington Church Street--London W8 4BA--United Kingdom',
#  '15 Kingly Street--London W1B 5PS--United Kingdom',
#  '145 Fleet Street--London EC4A 2BU--United Kingdom',
#  '36 Dean Street--London W1D 4PS--United Kingdom',
#  '103 Hampstead Road--London NW1 3EL--United Kingdom',
#  'One New Change--10 Bread Street--London EC4M 9AJ--United Kingdom',
#  '',
#  '15-17 Broadwick Street--London W1F 0DL--United Kingdom',
#  '34 Rupert Street--London W1D 6DN--United Kingdom',
#  '6 New Quebec Street--London W1H 7RQ--United Kingdom',
#  '6 Clapham Common South Side--London SW4 7AA--United Kingdom',
#  '20 Sherwood Street--London W1F 7ED--United Kingdom',
#  '62 Greenwich High Road--Greenwich--London SE10 8LF--United Kingdom',
#  "38 St John's Wood Terrace--London NW8 6LS--United Kingdom",
#  '35 Maiden Lane--London WC2E 7LB--United Kingdom',
#  '163-167 Bermondsey Street--London SE1 3UW--United Kingdom',
#  '144 Clerkenwell Road--London EC1R 5DP--United Kingdom',
#  '230 Shaftsbury Avenue--London WC2H 8EG--United Kingdom',
#  '26 Ganton Street--London W1F 7QZ--United Kingdom',
#  '23 Winchester Road--Swiss Cottage--London NW3 3NR--United Kingdom',
#  '252 High Holborn--London WC1V 7EN--United Kingdom',
#  '13 Coventry St--London W1D 7DH--United Kingdom',
#  '42 New Oxford Street--London WC1A 1EP--United Kingdom',
#  '21-22 Warwick Street--London W1B 5NE--United Kingdom',
#  '9 Regent Street--London SW1Y 4LR--United Kingdom',
#  '7-9 Battersea Square--London SW11 3RA--United Kingdom',
#  '6 Old Court Place--Kensington Church Street--London W8 4PL--United Kingdom',
#  '85 Piccadilly--London W1J 7NB--United Kingdom',
#  '65 Parkway Road--London NW1 7PP--United Kingdom',
#  '12 Archer Street--London W1D 7BB--United Kingdom',
#  '5A Burlington Gardens--London W1S 3EP--United Kingdom',
#  '',
#  '16 Henrietta Street--London WC2E 8QH--United Kingdom',
#  '8-9 Snowsfields--London SE1 3SU--United Kingdom',
#  '21 Heddon Street--London W1B 4BG--United Kingdom',
#  '80 Wardour Street--London W1F 0TF--United Kingdom',
#  '11 Greek Street--London W1D 4DJ--United Kingdom',
#  '12 Jerusalem Passage--London EC1V 4JP--United Kingdom',
#  '6 Bevis Marks--London EC3A 7BA--United Kingdom',
#  '73 Old Brompton Road--London SW7 3LD--United Kingdom',
#  '26 St John Street--London EC1M 4AY--United Kingdom',
#  '4 Lower Grosvenor Place--London SW1W 0EJ--United Kingdom',
#  '64 St Giles High Street--London WC2H 8LE--United Kingdom',
#  '106-110 Wardour Street--Soho W1F 0TR--United Kingdom',
#  '1st Floor Kingly Court--Carnaby Soho--London W1B 5PW--United Kingdom',
#  '46 De Beauvoir Crescent--London N1 5RY--United Kingdom',
#  '44 Narrow Street--London E14 8DP--United Kingdom',
#  '34-35 Southampton Street--London WC2E 7HG--United Kingdom',
#  '46 Lexington Street--London W1F 0LP--United Kingdom',
#  '2-5 Carthusian Street--London EC1M 6EB--United Kingdom',
#  '185 Portobello Road--Notting Hill W11 2ED--United Kingdom',
#  '191 Victoria St--London SW1E 5NE--United Kingdom',
#  "34 D'Arblay St--London W1F 8EY--United Kingdom",
#  '66 Knightsbridge--Mandarin Oriental at Hyde Park--London SW1X 7LA--United Kingdom',
#  '1 Chiltern Street--London W1U 7PA--United Kingdom',
#  '32 Henrietta Street--London WC2E 8NA--United Kingdom',
#  'Belvedere Road--London SE1 8XX--United Kingdom',
#  '49 Camberwell Church Street--London SE5 8TR--United Kingdom',
#  '58 Poland Street--London W1F 7NS--United Kingdom',
#  '',
#  '49 - 51 Black Prince Road--Lambeth--London SE11 6AB--United Kingdom',
#  '171 Farringdon Road--London EC1R 3AL--United Kingdom',
#  '26 Maddox Street--London W1S 1QH--United Kingdom',
#  '36 The Cut--London SE1 8LP--United Kingdom',
#  '214 Bermondsey St--London SE1 3TQ--United Kingdom',
#  '34 High Holborn--London WC1V 6AE--United Kingdom',
#  '',
#  '64 Charlotte Street--London W1T 4QD--United Kingdom',
#  'Arch 35a--85 Southwark Bridge Road--London SE1 0NQ--United Kingdom',
#  '176 Lower Road--London SE16 2UN--United Kingdom',
#  '273A Clapham Road--Stockwell--London SW9 9BQ--United Kingdom',
#  '1-7 Great St Thomas Apostle--London EC4V 2BH--United Kingdom',
#  "8 D'Arblay St--London W1F 8DP--United Kingdom",
#  '10 Berners Street--London W1T 3NP--United Kingdom',
#  '74 Blackfriars Road--London SE1 8HA--United Kingdom',
#  '5A Air Street--London W1J 0AD--United Kingdom',
#  '1 Blenheim Terrace--St Johns Wood--London NW8 0EH--United Kingdom',
#  '14 Borough High Street--London SE1 9QG--United Kingdom',
#  'Berkeley Square House--Berkeley Square--London W1J 6BR--United Kingdom',
#  '69 Rosebery Avenue--London EC1R 4RL--United Kingdom',
#  '85 Sloane Avenue--South Kensington--London SW3 3DX--United Kingdom',
#  '24 Floral Street--Covent Garden--London WC2E 9DP--United Kingdom',
#  '68-70 Shaftesbury Avenue--London W1D 6LY--United Kingdom',
#  '49 Frith Street--Soho W1D 4SG--United Kingdom',
#  "4 St James's Market--London SW1Y 4AH--United Kingdom",
#  '54-56 Great Eastern Street--London EC2A 3QR--United Kingdom',
#  '4-5 London Rd--London SE1 6JZ--United Kingdom',
#  "Gabriel's Wharf--56 Upper Ground--London SE1 9PP--United Kingdom",
#  '190 Sussex Gardens--London W2 1TU--United Kingdom',
#  '83-89 Fieldgate Street--London E1 1JU--United Kingdom',
#  '46 Churton Street--London SW1V 2LP--United Kingdom',
#  '217 Uxbridge Road--Shepherds Bush--London W12 9DH--United Kingdom',
#  '20 Mount Street--London W1K 2HE--United Kingdom',
#  '1st Floor 213 The Strand--Temple--London WC2R 1AP--United Kingdom',
#  "13 Neal's Yard--Covent Garden--London WC2H 9DP--United Kingdom",
#  '62 Wentworth St--London E1 7TF--United Kingdom',
#  '25 Winchester Road--London NW3 3NR--United Kingdom',
#  '24 Peter Street--London W1F--United Kingdom',
#  '134a Seven Sisters Road--London N7 7NS--United Kingdom',
#  '8A Thurloe Place--South Kensington--London SW7 2RX--United Kingdom',
#  '60 Penton Street--London N1 9PZ--United Kingdom',
#  '1st Floor--32 Southwark Street--London SE1 1TU--United Kingdom',
#  '92 Kensington Park Road--London W11 2PN--United Kingdom',
#  'New Crane Wharf--New Crane Place--Whapping--London E1W 3TU--United Kingdom',
#  '83 Southwark Street--London SE1 0HX--United Kingdom',
#  '160 Picadilly--London W1J 9EB--United Kingdom',
#  '15 Argyll Street--London W1F 7TP--United Kingdom',
#  '14-16 Rupert Street--London W1D 6DD--United Kingdom',
#  '27 Walham Grove--Fulham--London SW6 1QP--United Kingdom',
#  '92 Newman Street--London W1T 3EZ--United Kingdom',
#  '132 Brixton Hill--London SW2 1RS--United Kingdom',
#  '11 Stoney Street--London SE1 9AD--United Kingdom',
#  '22 Charlotte Street--London W1T 2NB--United Kingdom',
#  '77 Alie Street--Aldgate--London E1 8NH--United Kingdom',
#  '',
#  '75-77 Borough High Street--London SE1 1NH--United Kingdom',
#  '3 Kennington Lane--London SE11 4RG--United Kingdom',
#  '93-94 Wilton Road--London SW1V 1DW--United Kingdom',
#  '46 Berkeley Square--London W1J 5QB--United Kingdom',
#  '176 Bishopsgate--London EC2M 4NQ--United Kingdom',
#  '',
#  '152-156 North Gower street--London NW1 2LU--United Kingdom',
#  '107 Whitecross Street--KOREAN BBQ & VEGAN--LONDON--London EC1Y 8JD--United Kingdom',
#  '100 Cleveland Street--London W1T 6NS--United Kingdom',
#  '3 Bell Lane--London E1 7LA--United Kingdom',
#  '151 Sydney Street--London SW3 6NT--United Kingdom',
#  '4 Heddon Street--London W1B 4BS--United Kingdom',
#  'Railway Arch--102A Rockingham Street--London SE1 6PG--United Kingdom',
#  '164 Shepherds Bush Road--London W6 7PB--United Kingdom',
#  '2 Newport Place--Leicester Square--London WC2H 7JP--United Kingdom',
#  '1-3 Walton Street--London SW3 2JD--United Kingdom',
#  '38 Beauchamp Place--London SW3 1NU--United Kingdom',
#  '100 Leonard Street--London EC2A 4RH--United Kingdom',
#  '100 N End Road--London W14 9EX--United Kingdom',
#  '4 London Wall Buildings--Blomfield Street--London EC2M 5NT--United Kingdom',
#  '104 Bermondsey Street--London SE1 3UB--United Kingdom',
#  '111 Long Lane--London SE1 4PH--United Kingdom',
#  'Old Spitalfields Market--Brushfield Street--London E1 6BG--United Kingdom',
#  '50 Berwick Street--London W1F 8SJ--United Kingdom',
#  '42-44 Gaisford Street--London NW5 2ED--United Kingdom',
#  '11 Edgware Road--London W2 2ER--United Kingdom',
#  '31 Windmill Street--London W1T 2JN--United Kingdom',
#  '1 Redchurch Street--London E2 7DJ--United Kingdom',
#  '18-20 Bedford Hill--London SW12 9RG--United Kingdom',
#  '21 Piccadilly--London W1J 0BH--United Kingdom',
#  '44 High Street--Wanstead E11 2JR--United Kingdom',
#  '9 Chalton Street--London NW1 1JD--United Kingdom',
#  '6 Charlwood Street--London SW1V 2EE--United Kingdom',
#  '35-37 Heddon Street--London W1B 4BR--United Kingdom',
#  '9 Parkway--Camden Town--London NW1 7PG--United Kingdom',
#  'Great Portland Street Station--London W1W 5PW--United Kingdom',
#  '343 Kensington High st--London W8 6NW--United Kingdom',
#  '6-8 Mill Street--London W1S 2AZ--United Kingdom',
#  '3/5 Charing Cross Road--London WC2H 0HA--United Kingdom',
#  "16 Neal's Yard--Seven Dials--London WC2H 9DP--United Kingdom",
#  '243 Brompton Road--London SW3--United Kingdom',
#  '11 Wardour Street--London W1D 6PG--United Kingdom',
#  '4a Meard St--London W1F 0EF--United Kingdom',
#  '11A Islington High Street--London N1 9LQ--United Kingdom',
#  'Level 32 The Shard--31 St Thomas Street--London SE1 9SY--United Kingdom',
#  '49 Columbia Road--London E2 7RG--United Kingdom',
#  'One Hamilton Place--Park Lane--London W1J 7QY--United Kingdom',
#  'Kensington Palace--Palace Green--London W8 4PX--United Kingdom',
#  '192 Brick Lane--London E1 6SB--United Kingdom',
#  '8 Market Place--Fitzrovia--London W1W 8AG--United Kingdom',
#  '66 Bayswater Road--London W2 3PH--United Kingdom',
#  '',
#  '16-20 Chalton Street--London NW1 1JH--United Kingdom',
#  '10 Greek Street--London W1D 4DH--United Kingdom',
#  '1 Bedale Street--London SE1 9AL--United Kingdom',
#  '11 Berwick Street--London W1F 0PL--United Kingdom',
#  '117 Gloucester Road--London SW7 4ST--United Kingdom']

# %% [markdown]
# # Dataframe

# %%
restaurant_df = pd.DataFrame({'Name': name, 'Rating': rating, 'Reviews': reviews, 'Price Range in £': price_range, 'Number of Photos': nb_photos, 'Location': location})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ritth\code\Strive\Streamlit_project\fulldata_for_london_page2.ipynb Cell 26' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Streamlit_project/fulldata_for_london_page2.ipynb#ch0000017?line=0'>1</a> restaurant_df = pd.DataFrame({'Name':name, 'Rating':rating, 'Reviews': reviews, 'Price Range in £': price_range, 'Location': location})
#
# File ~\software\anaconda\envs\strive\lib\site-packages\pandas\core\frame.py:468, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/frame.py?line=462'>463</a>     mgr = self._init_mgr(
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/frame.py?line=463'>464</a>         data, axes=dict(index=index, columns=columns), dtype=dtype, copy=copy
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/frame.py?line=464'>465</a>     )
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/frame.py?line=466'>467</a> elif isinstance(data, dict):
# --> <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/frame.py?line=467'>468</a>     mgr = init_dict(data, index, columns, dtype=dtype)
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/frame.py?line=468'>469</a> elif isinstance(data, ma.MaskedArray):
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/frame.py?line=469'>470</a>     import numpy.ma.mrecords as mrecords
#
# File ~\software\anaconda\envs\strive\lib\site-packages\pandas\core\internals\construction.py:283, in init_dict(data, index, columns, dtype)
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=276'>277</a>     arrays = [
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=277'>278</a>         arr if not isinstance(arr, ABCIndexClass) else arr._data for arr in arrays
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=278'>279</a>     ]
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=279'>280</a>     arrays = [
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=280'>281</a>         arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=281'>282</a>     ]
# --> <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=282'>283</a> return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#
# File ~\software\anaconda\envs\strive\lib\site-packages\pandas\core\internals\construction.py:78, in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=74'>75</a> if verify_integrity:
#      <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=75'>76</a>     # figure out the index, if necessary
#      <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=76'>77</a>     if index is None:
# ---> <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=77'>78</a>         index = extract_index(arrays)
#      <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=78'>79</a>     else:
#      <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=79'>80</a>         index = ensure_index(index)
#
# File ~\software\anaconda\envs\strive\lib\site-packages\pandas\core\internals\construction.py:397, in extract_index(data)
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=394'>395</a> lengths = list(set(raw_lengths))
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=395'>396</a> if len(lengths) > 1:
# --> <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=396'>397</a>     raise ValueError("arrays must all be same length")
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=398'>399</a> if have_dicts:
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=399'>400</a>     raise ValueError(
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=400'>401</a>         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/strive/lib/site-packages/pandas/core/internals/construction.py?line=401'>402</a>     )
#
# ValueError: arrays must all be same length

# %%
# store data
restaurant_df.to_csv('restaurant_data.csv', index=False)

# %%
#restaurant_df.head()

# %%
#restaurant_df.info()

# %%
# Missing values
#restaurant_df.isnull().sum().sort_values(ascending=False)

# %%
# duplicates values
#restaurant_df[restaurant_df.duplicated()]

# %% [markdown]
# ### Changing Price value

# %%
# Price range (price per person)
# Based on information from yelp and Quora:
# $= under $10. $$=11-30. $$$=31-60. $$$$= over $61
# Converting to pound

# 1 pound = 1.31 USD
Euro = (pd.Series([10, 11, 30, 31, 60, 61]) * 1.31).apply(lambda x: int(x))
#print(Euro)
mapper = {'£':'under 13', '££':'[14 - 39]', '£££':'[40 - 78]', '££££':'over 79'}
restaurant_df['Price Range'] = restaurant_df['Price Range'].map(mapper)

# %%
# Top 20 Most reviews

#restaurant_df.sort_values(by='Reviews', ascending=False).head(20)

# %%
# Rating and number of reviews
restaurant_df['Rating'] = restaurant_df['Rating'].apply(lambda x: float(x)) 
restaurant_df['Reviews'] = restaurant_df['Reviews'].apply(lambda x: float(x))

#restaurant_df.describe()

# %% [markdown]
# # Hotels

# %%
#  1 webscraping Hotels
# Monitoring of the loop
start_time = time()
request = 0

# Dictionary for storing web content
soup_r = {}
for start_num in range(0, 240, 10):

    # Make a request
    url = f"https://www.yelp.com/search?find_desc=Hotels&find_loc=london&start={start_num}"
    response = requests.get(url)

    # Pause the loop
    sleep(randint(8,15))
    print(response)
    page = BeautifulSoup(response.content, 'html.parser')
    soup_r[start_num] = page


    # Monitor the requests
    request += 1
    elapsed_time = time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))
    #clear_output(wait = True)

    # Throw a warning if request wasn't successful
    if response.status_code != 200:
        warn('Request: {}; Status code: {}'.format(request, response.status_code))
# Out:
# <Response [200]>
# Request:1; Frequency: 0.07463168799767089 requests/s
# <Response [200]>
# Request:2; Frequency: 0.0810789257055489 requests/s
# <Response [200]>
# Request:3; Frequency: 0.07639726925847587 requests/s
# <Response [200]>
# Request:4; Frequency: 0.07302651125520489 requests/s
# <Response [200]>
# Request:5; Frequency: 0.07431678131883682 requests/s
# <Response [200]>
# Request:6; Frequency: 0.07423896176165527 requests/s
# <Response [200]>
# Request:7; Frequency: 0.07653986888991388 requests/s
# <Response [200]>
# Request:8; Frequency: 0.0731284092638863 requests/s
# <Response [200]>
# Request:9; Frequency: 0.07274786867575989 requests/s
# <Response [200]>
# Request:10; Frequency: 0.07377396962673882 requests/s
# <Response [200]>
# Request:11; Frequency: 0.07514750668655451 requests/s
# <Response [200]>
# Request:12; Frequency: 0.07646583510638981 requests/s
# <Response [200]>
# Request:13; Frequency: 0.07563615662989248 requests/s
# <Response [200]>
# Request:14; Frequency: 0.07557877191219448 requests/s
# <Response [200]>
# Request:15; Frequency: 0.0757331003344842 requests/s
# <Response [200]>
# Request:16; Frequency: 0.07471744306743144 requests/s
# <Response [200]>
# Request:17; Frequency: 0.07455111698112397 requests/s
# <Response [200]>
# Request:18; Frequency: 0.07478163941391165 requests/s
# <Response [200]>
# Request:19; Frequency: 0.07354108661954355 requests/s
# <Response [200]>
# Request:20; Frequency: 0.07282930118131321 requests/s
# <Response [200]>
# Request:21; Frequency: 0.07237840055650399 requests/s
# <Response [200]>
# Request:22; Frequency: 0.07048936492092682 requests/s
# <Response [504]>
# Request:23; Frequency: 0.06852482148861296 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_50924\1228871983.py:29: UserWarning: Request: 23; Status code: 504
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [200]>
# Request:24; Frequency: 0.0680124365147564 requests/s

# %%
hotel_soup = pd.DataFrame([soup_r]).squeeze()

# %%
# save to csv
pd.DataFrame([soup_r]).to_csv('hotel_soup.csv')

# %% [markdown]
# ## Page2

# %%
# details about each business
request = 0
start_time = time()

soup_h2 = pd.DataFrame() 
ser = pd.read_csv('C:\\Users\\ritth\\code\\Strive\\Streamlit_project\\hotel_soup.csv').drop(columns='Unnamed: 0').squeeze()
for row in ser [:13:-1]:
    page = BeautifulSoup(row, 'html.parser')
    a_tags = page.select('.css-1egxyvc .css-1m051bw')
    for tag in a_tags:
        # print(tag)
        name = tag.text
        link = tag['href']
        url = f'https://wwww.yelp.com{link}'
        response = requests.get(url)

        # Pause the loop
        sleep(randint(8,15))
        print(response)
        page = BeautifulSoup(response.content, 'html.parser')
        soup_h2[name] = [page]

        # Monitor the requests
        request += 1
        elapsed_time = time() - start_time
        print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))

        # Throw a warning if request wasn't successful
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(request, response.status_code))
# Out:
# <Response [200]>
# Request:1; Frequency: 0.03390039639332068 requests/s
# <Response [200]>
# Request:2; Frequency: 0.04168706371180742 requests/s
# <Response [200]>
# Request:3; Frequency: 0.04985962296066158 requests/s
# <Response [200]>
# Request:4; Frequency: 0.055913099025349286 requests/s
# <Response [200]>
# Request:5; Frequency: 0.05430897747919184 requests/s
# <Response [200]>
# Request:6; Frequency: 0.057060215291334974 requests/s
# <Response [200]>
# Request:7; Frequency: 0.05556416939415652 requests/s
# <Response [200]>
# Request:8; Frequency: 0.057051678329218376 requests/s
# <Response [200]>
# Request:9; Frequency: 0.05757235111029915 requests/s
# <Response [200]>
# Request:10; Frequency: 0.05878698638980737 requests/s
# <Response [200]>
# Request:11; Frequency: 0.05846100447877241 requests/s
# <Response [200]>
# Request:12; Frequency: 0.05830349778777442 requests/s
# <Response [200]>
# Request:13; Frequency: 0.05921762014529475 requests/s
# <Response [200]>
# Request:14; Frequency: 0.05923616508676002 requests/s
# <Response [200]>
# Request:15; Frequency: 0.059580452307350144 requests/s
# <Response [200]>
# Request:16; Frequency: 0.0592167972238992 requests/s
# <Response [200]>
# Request:17; Frequency: 0.06034032673107699 requests/s
# <Response [200]>
# Request:18; Frequency: 0.06126602895824379 requests/s
# <Response [200]>
# Request:19; Frequency: 0.0612114064336953 requests/s
# <Response [200]>
# Request:20; Frequency: 0.06170428331702907 requests/s
# <Response [200]>
# Request:21; Frequency: 0.06172957279732893 requests/s
# <Response [200]>
# Request:22; Frequency: 0.06138711842271001 requests/s
# <Response [200]>
# Request:23; Frequency: 0.060968193330961616 requests/s
# <Response [200]>
# Request:24; Frequency: 0.06038700499133545 requests/s
# <Response [200]>
# Request:25; Frequency: 0.060167138070763786 requests/s
# <Response [200]>
# Request:26; Frequency: 0.05986101977318834 requests/s
# <Response [200]>
# Request:27; Frequency: 0.059785097891010136 requests/s
# <Response [200]>
# Request:28; Frequency: 0.0595096642830081 requests/s
# <Response [200]>
# Request:29; Frequency: 0.05998359692345064 requests/s
# <Response [200]>
# Request:30; Frequency: 0.059906609194629326 requests/s
# <Response [200]>
# Request:31; Frequency: 0.06047267835878879 requests/s
# <Response [200]>
# Request:32; Frequency: 0.0607566059215562 requests/s
# <Response [200]>
# Request:33; Frequency: 0.060890103952434056 requests/s
# <Response [200]>
# Request:34; Frequency: 0.06074717058928529 requests/s
# <Response [200]>
# Request:35; Frequency: 0.06089864301667832 requests/s
# <Response [200]>
# Request:36; Frequency: 0.06102989702153419 requests/s
# <Response [200]>
# Request:37; Frequency: 0.06096979786298837 requests/s
# <Response [200]>
# Request:38; Frequency: 0.061060593945557226 requests/s
# <Response [200]>
# Request:39; Frequency: 0.061225251900046525 requests/s
# <Response [200]>
# Request:40; Frequency: 0.06107540963391836 requests/s
# <Response [200]>
# Request:41; Frequency: 0.06147891122036485 requests/s
# <Response [200]>
# Request:42; Frequency: 0.06169285960619318 requests/s
# <Response [200]>
# Request:43; Frequency: 0.06180593115886345 requests/s
# <Response [200]>
# Request:44; Frequency: 0.06162203615310271 requests/s
# <Response [200]>
# Request:45; Frequency: 0.06150614106526389 requests/s
# <Response [200]>
# Request:46; Frequency: 0.061657979295555755 requests/s
# <Response [200]>
# Request:47; Frequency: 0.061873746507780256 requests/s
# <Response [200]>
# Request:48; Frequency: 0.06174796264971231 requests/s
# <Response [200]>
# Request:49; Frequency: 0.06155115852671598 requests/s
# <Response [200]>
# Request:50; Frequency: 0.061585877270656085 requests/s
# <Response [200]>
# Request:51; Frequency: 0.06164200037134385 requests/s
# <Response [200]>
# Request:52; Frequency: 0.061796130351833525 requests/s
# <Response [200]>
# Request:53; Frequency: 0.061698458642565485 requests/s
# <Response [200]>
# Request:54; Frequency: 0.06196678529993477 requests/s
# <Response [200]>
# Request:55; Frequency: 0.06199977050378959 requests/s
# <Response [200]>
# Request:56; Frequency: 0.06213944020171623 requests/s
# <Response [200]>
# Request:57; Frequency: 0.06222389906952249 requests/s
# <Response [200]>
# Request:58; Frequency: 0.0621863422887175 requests/s
# <Response [200]>
# Request:59; Frequency: 0.06210382802956298 requests/s
# <Response [200]>
# Request:60; Frequency: 0.062331081272615836 requests/s
# <Response [200]>
# Request:61; Frequency: 0.062203476018211606 requests/s
# <Response [200]>
# Request:62; Frequency: 0.06214733237722325 requests/s
# <Response [200]>
# Request:63; Frequency: 0.06210213173585092 requests/s
# <Response [200]>
# Request:64; Frequency: 0.06234561056722383 requests/s
# <Response [200]>
# Request:65; Frequency: 0.06251769659918752 requests/s
# <Response [200]>
# Request:66; Frequency: 0.06248105454377445 requests/s
# <Response [200]>
# Request:67; Frequency: 0.062488853959581515 requests/s
# <Response [200]>
# Request:68; Frequency: 0.0622527506915569 requests/s
# <Response [200]>
# Request:69; Frequency: 0.062341018375493336 requests/s
# <Response [200]>
# Request:70; Frequency: 0.06222664649866044 requests/s
# <Response [200]>
# Request:71; Frequency: 0.06213240165435034 requests/s
# <Response [200]>
# Request:72; Frequency: 0.062299695375914066 requests/s
# <Response [200]>
# Request:73; Frequency: 0.06248345137437752 requests/s
# <Response [200]>
# Request:74; Frequency: 0.062339450783346774 requests/s
# <Response [200]>
# Request:75; Frequency: 0.06253742399963763 requests/s
# <Response [200]>
# Request:76; Frequency: 0.06253481524853803 requests/s
# <Response [200]>
# Request:77; Frequency: 0.06249800894414674 requests/s
# <Response [200]>
# Request:78; Frequency: 0.06230678336531753 requests/s
# <Response [200]>
# Request:79; Frequency: 0.062228804860275294 requests/s
# <Response [200]>
# Request:80; Frequency: 0.06238791927718596 requests/s
# <Response [200]>
# Request:81; Frequency: 0.06258485721208193 requests/s
# <Response [200]>
# Request:82; Frequency: 0.06249229386980516 requests/s
# <Response [200]>
# Request:83; Frequency: 0.06232791515071043 requests/s
# <Response [200]>
# Request:84; Frequency: 0.062363940395660435 requests/s
# <Response [200]>
# Request:85; Frequency: 0.06222099848409383 requests/s
# <Response [200]>
# Request:86; Frequency: 0.062142724730941415 requests/s
# <Response [200]>
# Request:87; Frequency: 0.06207430397370703 requests/s
# <Response [200]>
# Request:88; Frequency: 0.06215061791401451 requests/s
# <Response [200]>
# Request:89; Frequency: 0.06202067255854666 requests/s
# <Response [200]>
# Request:90; Frequency: 0.061982828685373484 requests/s
# <Response [200]>
# Request:91; Frequency: 0.06209559398825156 requests/s
# <Response [200]>
# Request:92; Frequency: 0.06221846815411489 requests/s
# <Response [200]>
# Request:93; Frequency: 0.062295840395927865 requests/s
# <Response [200]>
# Request:94; Frequency: 0.06237427250218262 requests/s
# <Response [200]>
# Request:95; Frequency: 0.06239883770824391 requests/s
# <Response [200]>
# Request:96; Frequency: 0.06248359027308906 requests/s
# <Response [200]>
# Request:97; Frequency: 0.06252949475576106 requests/s
# <Response [200]>
# Request:98; Frequency: 0.062481290589683096 requests/s
# <Response [200]>
# Request:99; Frequency: 0.06238926975269639 requests/s
# <Response [200]>
# Request:100; Frequency: 0.06232430873730825 requests/s

# %%
# page2 store in csv, for reuse
soup_h2.to_csv('hotel_soup2.csv')

# %%
hotel_soup2 = pd.read_csv('C:\\Users\\ritth\\code\\Strive\\Streamlit_project\\hotel_soup2.csv').drop(columns='Unnamed: 0').squeeze()

# %% [markdown]
# ### Name

# %%
name = []
for row in hotel_soup:  
    result = row.select('.css-1egxyvc .css-1m051bw') 
    for tag in result:
        #print(tag.text)
        name.append(tag.text)

# %%
#pd.Series(name).value_counts()

# %% [markdown]
# ### Ratings

# %%
rating = []
container_class = 'container__09f24__mpR8_ hoverable__09f24__wQ_on margin-t3__09f24__riq4X margin-b3__09f24__l9v5d padding-t3__09f24__TMrIW padding-r3__09f24__eaF7p padding-b3__09f24__S8R2d padding-l3__09f24__IOjKY border--top__09f24__exYYb border--right__09f24__X7Tln border--bottom__09f24___mg5X border--left__09f24__DMOkM border-color--default__09f24__NPAKY'
for row in hotel_soup:
    result = row.find_all(class_ = container_class)

    for tag in result:
        header_text = tag.div.div.div.nextSibling.div
        rat = header_text.select_one('.overflow--hidden__09f24___ayzG')
        if rat is not None:
            rating.append(rat['aria-label'].split()[0])
        else:
            rating.append(np.nan)

# %%
# test
# for n, rat in zip(name, rating):
#     print(n, rat)

# %% [markdown]
# ### Reviews

# %%
reviews = []
container_class = 'container__09f24__mpR8_ hoverable__09f24__wQ_on margin-t3__09f24__riq4X margin-b3__09f24__l9v5d padding-t3__09f24__TMrIW padding-r3__09f24__eaF7p padding-b3__09f24__S8R2d padding-l3__09f24__IOjKY border--top__09f24__exYYb border--right__09f24__X7Tln border--bottom__09f24___mg5X border--left__09f24__DMOkM border-color--default__09f24__NPAKY'
for row in hotel_soup:
    result = row.find_all(class_ = container_class)

    for tag in result:
        header_text = tag.div.div.div.nextSibling.div
        rev = header_text.select_one('.reviewCount__09f24__tnBk4')
        if rev is not None:
            reviews.append(rev.text)
        else:
            reviews.append(np.nan)

# %%
# test
# for n, rev in zip(name, reviews):
#     print(n, rev)

# %% [markdown]
# ### Price

# %%
price_range = []
container_class = 'container__09f24__mpR8_ hoverable__09f24__wQ_on margin-t3__09f24__riq4X margin-b3__09f24__l9v5d padding-t3__09f24__TMrIW padding-r3__09f24__eaF7p padding-b3__09f24__S8R2d padding-l3__09f24__IOjKY border--top__09f24__exYYb border--right__09f24__X7Tln border--bottom__09f24___mg5X border--left__09f24__DMOkM border-color--default__09f24__NPAKY'
for row in hotel_soup:
    result = row.find_all(class_ = container_class)

    for tag in result:
        header_text = tag.div.div.div.nextSibling.div
        price = header_text.select_one('.css-1s7bx9e')
        if price is not None:
            price_range.append(price.text)
        else:
            price_range.append(np.nan)

# %%
# test
# for n, price in zip(name, price_range):
#     print(n, price)

# %% [markdown]
# ### Location

# %%
location = [] 
for row in hotel_soup2:
    soup = BeautifulSoup(row, 'html.parser')
    result = soup.select('address .raw__09f24__T4Ezm')

    adress_elements = []
    for tag in result:
        adress_elements.append(tag.text)
    location.append( '--'.join(adress_elements) )

# %%
location
# Out:
# ['Great Portland Street Station--London W1W 5PW--United Kingdom',
#  '8 Market Place--Fitzrovia--London W1W 8AG--United Kingdom',
#  '66 Bayswater Road--London W2 3PH--United Kingdom',
#  '94 Camden Road--London NW1 9EA--United Kingdom',
#  '16-20 Chalton Street--London NW1 1JH--United Kingdom',
#  '10 Greek Street--London W1D 4DH--United Kingdom',
#  '58 Bethnal Green Road--London E1 6JW--United Kingdom',
#  '1 Bedale Street--London SE1 9AL--United Kingdom',
#  '11 Berwick Street--London W1F 0PL--United Kingdom',
#  '117 Gloucester Road--London SW7 4ST--United Kingdom',
#  '3/5 Charing Cross Road--London WC2H 0HA--United Kingdom',
#  '',
#  '11 Wardour Street--London W1D 6PG--United Kingdom',
#  '4a Meard St--London W1F 0EF--United Kingdom',
#  'Level 32 The Shard--31 St Thomas Street--London SE1 9SY--United Kingdom',
#  '49 Columbia Road--London E2 7RG--United Kingdom',
#  '11A Islington High Street--London N1 9LQ--United Kingdom',
#  'One Hamilton Place--Park Lane--London W1J 7QY--United Kingdom',
#  'Kensington Palace--Palace Green--London W8 4PX--United Kingdom',
#  '192 Brick Lane--London E1 6SB--United Kingdom',
#  '343 Kensington High st--London W8 6NW--United Kingdom',
#  '104 Bermondsey Street--London SE1 3UB--United Kingdom',
#  '111 Long Lane--London SE1 4PH--United Kingdom',
#  '6-8 Mill Street--London W1S 2AZ--United Kingdom',
#  "16 Neal's Yard--Seven Dials--London WC2H 9DP--United Kingdom",
#  '44 High Street--Wanstead E11 2JR--United Kingdom',
#  '18-20 Bedford Hill--London SW12 9RG--United Kingdom',
#  '9 Chalton Street--London NW1 1JD--United Kingdom',
#  '6 Charlwood Street--London SW1V 2EE--United Kingdom',
#  '35-37 Heddon Street--London W1B 4BR--United Kingdom',
#  '21 Piccadilly--London W1J 0BH--United Kingdom',
#  '31 Windmill Street--London W1T 2JN--United Kingdom',
#  '9 Parkway--Camden Town--London NW1 7PG--United Kingdom',
#  '17-18 Henrietta Street--Covent Garden WC2E 8QH--United Kingdom',
#  'Old Spitalfields Market--Brushfield Street--London E1 6BG--United Kingdom',
#  '50 Berwick Street--London W1F 8SJ--United Kingdom',
#  '42-44 Gaisford Street--London NW5 2ED--United Kingdom',
#  '',
#  '1 Redchurch Street--London E2 7DJ--United Kingdom',
#  '46 Berkeley Square--London W1J 5QB--United Kingdom',
#  '38 Beauchamp Place--London SW3 1NU--United Kingdom',
#  '100 Leonard Street--London EC2A 4RH--United Kingdom',
#  '100 N End Road--London W14 9EX--United Kingdom',
#  '3 Bell Lane--London E1 7LA--United Kingdom',
#  '6 Bevis Marks--London EC3A 7BA--United Kingdom',
#  '4 London Wall Buildings--Blomfield Street--London EC2M 5NT--United Kingdom',
#  '4 Heddon Street--London W1B 4BS--United Kingdom',
#  '151 Sydney Street--London SW3 6NT--United Kingdom',
#  '100 Cleveland Street--London W1T 6NS--United Kingdom',
#  '152-156 North Gower street--London NW1 2LU--United Kingdom',
#  'Railway Arch--102A Rockingham Street--London SE1 6PG--United Kingdom',
#  '164 Shepherds Bush Road--London W6 7PB--United Kingdom',
#  '176 Bishopsgate--London EC2M 4NQ--United Kingdom',
#  '2 Newport Place--Leicester Square--London WC2H 7JP--United Kingdom',
#  '1-3 Walton Street--London SW3 2JD--United Kingdom',
#  '22 Charlotte Street--London W1T 2NB--United Kingdom',
#  '77 Alie Street--Aldgate--London E1 8NH--United Kingdom',
#  '75-77 Borough High Street--London SE1 1NH--United Kingdom',
#  '3 Stroud Green Road--London N4 2DQ--United Kingdom',
#  '92 Newman Street--London W1T 3EZ--United Kingdom',
#  '107 Whitecross Street--KOREAN BBQ & VEGAN--LONDON--London EC1Y 8JD--United Kingdom',
#  '132 Brixton Hill--London SW2 1RS--United Kingdom',
#  '11 Stoney Street--London SE1 9AD--United Kingdom',
#  '50 Artillery Lane--London E1 7LJ--United Kingdom',
#  '3 Kennington Lane--London SE11 4RG--United Kingdom',
#  '93-94 Wilton Road--London SW1V 1DW--United Kingdom',
#  '60 Penton Street--London N1 9PZ--United Kingdom',
#  '1st Floor--32 Southwark Street--London SE1 1TU--United Kingdom',
#  '92 Kensington Park Road--London W11 2PN--United Kingdom',
#  '1-7 Great St Thomas Apostle--London EC4V 2BH--United Kingdom',
#  'New Crane Wharf--New Crane Place--Whapping--London E1W 3TU--United Kingdom',
#  '83 Southwark Street--London SE1 0HX--United Kingdom',
#  '160 Picadilly--London W1J 9EB--United Kingdom',
#  '15 Argyll Street--London W1F 7TP--United Kingdom',
#  '14-16 Rupert Street--London W1D 6DD--United Kingdom',
#  '27 Walham Grove--Fulham--London SW6 1QP--United Kingdom']

# %% [markdown]
# ### Photos

# %%
nb_photos = []
photo_header_class = 'photo-header-content-container__09f24__jDLBB border-color--default__09f24__NPAKY'
for row in hotel_soup2:
    soup = BeautifulSoup(row, 'html.parser')
    photo_header = soup.find(class_ = photo_header_class)

    if photo_header is not None:
        nb_photos.append(  pd.Series(photo_header.text).str.extract(r'See (\d+) photos').squeeze()  )
    else:
        nb_photos.append(np.nan)

# %%
# df numbers of photo
for name, photo in zip(hotel_soup2.index, nb_photos):
    print(name, photo)
# Out:
# Istanbul Cafe Bistro 35
# Sweet Chick 25
# The Swan 124
# Domo 94 18
# Albertini Restaurant 95
# 10 Greek Street 87
# Lahpet 31
# Flor 5
# Polpetto 38
# Nando’s 101
# Steak & Co 126
# L’ETO nan
# Misato 132
# Honest Burgers Meard St - Soho 259
# Oblix At The Shard 367
# Brawn 84
# German Doner Kebab 5
# Ella Canta 41
# The Orangery 508
# Cereal Killer Cafe 335
# Romulo Cafe 70
# José 120
# The Old School Yard 44
# The Windmill 99
# The Barbary 232
# Otto Restaurant nan
# Milk 67
# Yatri Indian Restaurant 20
# CASK Pub and Kitchen 68
# Sabor 50
# Terrace Grill and Bar 26
# BAO 262
# Mamak Don 35
# Flat Iron 412
# Dumpling Shack 27
# The Real Greek - Soho 66
# The Lion & Unicorn 20
# Al Balad nan
# Andina 228
# Annabel’s 23
# Maroush II 99
# The Book Club 79
# Eat Aroi Thai 22
# Balaio Brazilian Grill nan
# The Alchemist 191
# Bierschenke 38
# Rumours nan
# Phat Phuc Noodle Bar 96
# Oriental Dragon Restaurant 5
# VQ Euston 22
# Costa Azul 6
# Kerbisher & Malt 88
# Polo 24 Hour Bar 177
# Tokyo Diner 176
# Scalini Restaurant 69
# The Ninth London 102
# Emilia’s Crafted Pasta - Aldgate 20
# The George Inn 145
# Dotori 49
# Laksamania 41
# Korean Bbq and Vegan 27
# Negril 28
# Wright Brothers 183
# Ottolenghi 195
# The Lobster Pot 17
# Kazan 81
# Liman Kitchen 20
# Casa do Frango 28
# Core by Clare Smyth 190
# Thai Square 18
# River View Chinese Restaurant nan
# The Table 521
# The Wolseley 836
# Wok to Walk - Oxford St 91
# Waxy O’Connor’s 94
# The Harwood Arms 282

# %% [markdown]
# # Dataframe

# %%
hotel_df = pd.DataFrame({'Name':name, 'Rating':rating, 'Reviews': reviews, 'Price Range in £': price_range, 'Number of Photos': nb_photos, 'Location': location})

# %%
# store data
hotel_df.to_csv('hotels_data.csv', index=False)

# %%
#hotel_df.head()

# %%
#hotel_df.info()

# %% [markdown]
# ### Changing price value

# %%
# 1 pound = 1.31 USD
Euro = (pd.Series([10, 11, 30, 31, 60, 61]) * 1.31).apply(lambda x: int(x))
#print(Euro)
mapper = {'£':'under 13', '££':'[14 - 39]', '£££':'[40 - 78]', '££££':'over 79'}
hotel_df['Price Range'] = hotel_df['Price Range'].map(mapper)

# %%
# Top 20 Most reviews

#hotel_df.sort_values(by='Reviews', ascending=False).head(20)

# %% [markdown]
# # Pubs

# %%
#  1 webscraping Hotels
# Monitoring of the loop
start_time = time()
request = 0

# Dictionary for storing web content
soup_r = {}
for start_num in range(0, 240, 10):

    # Make a request
    url = f"https://www.yelp.com/search?find_desc=Pubs&find_loc=london&start={start_num}"
    response = requests.get(url)

    # Pause the loop
    sleep(randint(8,15))
    print(response)
    page = BeautifulSoup(response.content, 'html.parser')
    soup_r[start_num] = page


    # Monitor the requests
    request += 1
    elapsed_time = time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))
    #clear_output(wait = True)

    # Throw a warning if request wasn't successful
    if response.status_code != 200:
        warn('Request: {}; Status code: {}'.format(request, response.status_code))
# Out:
# <Response [200]>
# Request:1; Frequency: 0.055978888012875226 requests/s
# <Response [200]>
# Request:2; Frequency: 0.06432428820572367 requests/s
# <Response [200]>
# Request:3; Frequency: 0.06196366985978857 requests/s
# <Response [200]>
# Request:4; Frequency: 0.06384052580932645 requests/s
# <Response [200]>
# Request:5; Frequency: 0.0667055806303426 requests/s
# <Response [200]>
# Request:6; Frequency: 0.06866049150451571 requests/s
# <Response [200]>
# Request:7; Frequency: 0.06884773721454789 requests/s
# <Response [200]>
# Request:8; Frequency: 0.06827174648907999 requests/s
# <Response [200]>
# Request:9; Frequency: 0.06897364276292706 requests/s
# <Response [200]>
# Request:10; Frequency: 0.06856888637703656 requests/s
# <Response [200]>
# Request:11; Frequency: 0.06859819701070921 requests/s
# <Response [200]>
# Request:12; Frequency: 0.06788737386487426 requests/s
# <Response [200]>
# Request:13; Frequency: 0.06739759838064563 requests/s
# <Response [200]>
# Request:14; Frequency: 0.06748933074418786 requests/s
# <Response [200]>
# Request:15; Frequency: 0.0674880729671538 requests/s
# <Response [200]>
# Request:16; Frequency: 0.06675431660452916 requests/s
# <Response [200]>
# Request:17; Frequency: 0.06636909340893933 requests/s
# <Response [200]>
# Request:18; Frequency: 0.06744346047949813 requests/s
# <Response [200]>
# Request:19; Frequency: 0.06784390636306059 requests/s
# <Response [200]>
# Request:20; Frequency: 0.06791964487155389 requests/s
# <Response [200]>
# Request:21; Frequency: 0.06617645345153607 requests/s
# <Response [200]>
# Request:22; Frequency: 0.06587275208196829 requests/s
# <Response [200]>
# Request:23; Frequency: 0.0654617027018128 requests/s
# <Response [200]>
# Request:24; Frequency: 0.06632568636013546 requests/s

# %%
pub_soup = pd.DataFrame([soup_r]).squeeze()

# %%
# save to csv
pd.DataFrame([soup_r]).to_csv('pub_soup.csv')

# %% [markdown]
# ## Page2

# %%
# details about each business
request = 0
start_time = time()

soup_p2 = pd.DataFrame() 
ser = pd.read_csv('C:\\Users\\ritth\\code\\Strive\\Streamlit_project\\pub_soup.csv').drop(columns='Unnamed: 0').squeeze()
for row in ser:
    page = BeautifulSoup(row, 'html.parser')
    a_tags = page.select('.css-1egxyvc .css-1m051bw')
    for tag in a_tags:
        # print(tag)
        name = tag.text
        link = tag['href']
        url = f'https://wwww.yelp.com{link}'
        response = requests.get(url)

        # Pause the loop
        sleep(randint(8,15))
        print(response)
        page = BeautifulSoup(response.content, 'html.parser')
        soup_p2[name] = [page]

        # Monitor the requests
        request += 1
        elapsed_time = time() - start_time
        print('Request:{}; Frequency: {} requests/s'.format(request, request/elapsed_time))

        # Throw a warning if request wasn't successful
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(request, response.status_code))
# Out:
# <Response [200]>
# Request:1; Frequency: 0.07343866857114782 requests/s
# <Response [200]>
# Request:2; Frequency: 0.06371788385791753 requests/s
# <Response [200]>
# Request:3; Frequency: 0.06403239920589703 requests/s
# <Response [200]>
# Request:4; Frequency: 0.06164845312162167 requests/s
# <Response [200]>
# Request:5; Frequency: 0.06298265502011074 requests/s
# <Response [200]>
# Request:6; Frequency: 0.06447428234806649 requests/s
# <Response [200]>
# Request:7; Frequency: 0.061673383207011316 requests/s
# <Response [200]>
# Request:8; Frequency: 0.06252872866825802 requests/s
# <Response [200]>
# Request:9; Frequency: 0.06313043209254054 requests/s
# <Response [200]>
# Request:10; Frequency: 0.06336095455710537 requests/s
# <Response [200]>
# Request:11; Frequency: 0.06228677591729176 requests/s
# <Response [200]>
# Request:12; Frequency: 0.06198800788943441 requests/s
# <Response [200]>
# Request:13; Frequency: 0.06219722776995394 requests/s
# <Response [200]>
# Request:14; Frequency: 0.06200924305620604 requests/s
# <Response [200]>
# Request:15; Frequency: 0.0614038897755978 requests/s
# <Response [200]>
# Request:16; Frequency: 0.06155989151453604 requests/s
# <Response [200]>
# Request:17; Frequency: 0.061892249239294726 requests/s
# <Response [200]>
# Request:18; Frequency: 0.061682192810966374 requests/s
# <Response [200]>
# Request:19; Frequency: 0.06161276050523307 requests/s
# <Response [200]>
# Request:20; Frequency: 0.06139868056172099 requests/s
# <Response [200]>
# Request:21; Frequency: 0.062137189407522886 requests/s
# <Response [200]>
# Request:22; Frequency: 0.06199402134422237 requests/s
# <Response [200]>
# Request:23; Frequency: 0.06188800026256645 requests/s
# <Response [200]>
# Request:24; Frequency: 0.06136160205174092 requests/s
# <Response [200]>
# Request:25; Frequency: 0.061961210136040085 requests/s
# <Response [200]>
# Request:26; Frequency: 0.06195208780423983 requests/s
# <Response [200]>
# Request:27; Frequency: 0.061630039865810525 requests/s
# <Response [200]>
# Request:28; Frequency: 0.06157534121265036 requests/s
# <Response [200]>
# Request:29; Frequency: 0.06134515370134348 requests/s
# <Response [200]>
# Request:30; Frequency: 0.06136668646618966 requests/s
# <Response [200]>
# Request:31; Frequency: 0.06152553051749178 requests/s
# <Response [200]>
# Request:32; Frequency: 0.06164860642573797 requests/s
# <Response [200]>
# Request:33; Frequency: 0.06140519488245625 requests/s
# <Response [200]>
# Request:34; Frequency: 0.0619339766975688 requests/s
# <Response [200]>
# Request:35; Frequency: 0.061475214526038734 requests/s
# <Response [200]>
# Request:36; Frequency: 0.06100592701678553 requests/s
# <Response [200]>
# Request:37; Frequency: 0.06070591460091279 requests/s
# <Response [200]>
# Request:38; Frequency: 0.06096939086903381 requests/s
# <Response [200]>
# Request:39; Frequency: 0.06077123608026912 requests/s
# <Response [200]>
# Request:40; Frequency: 0.06018378966503162 requests/s
# <Response [200]>
# Request:41; Frequency: 0.06032782707252505 requests/s
# <Response [200]>
# Request:42; Frequency: 0.059356073470964374 requests/s
# <Response [200]>
# Request:43; Frequency: 0.059442538528336426 requests/s
# <Response [200]>
# Request:44; Frequency: 0.05958276993767681 requests/s
# <Response [200]>
# Request:45; Frequency: 0.059241602616416734 requests/s
# <Response [200]>
# Request:46; Frequency: 0.0592281948721589 requests/s
# <Response [200]>
# Request:47; Frequency: 0.05902203380782798 requests/s
# <Response [200]>
# Request:48; Frequency: 0.05935083042864599 requests/s
# <Response [200]>
# Request:49; Frequency: 0.059629384282320994 requests/s
# <Response [200]>
# Request:50; Frequency: 0.05977921587367042 requests/s
# <Response [200]>
# Request:51; Frequency: 0.05953099566149504 requests/s
# <Response [200]>
# Request:52; Frequency: 0.05943091757931568 requests/s
# <Response [200]>
# Request:53; Frequency: 0.05938050392645271 requests/s
# <Response [200]>
# Request:54; Frequency: 0.059604911256188 requests/s
# <Response [200]>
# Request:55; Frequency: 0.05943297845613478 requests/s
# <Response [200]>
# Request:56; Frequency: 0.05961924286285254 requests/s
# <Response [200]>
# Request:57; Frequency: 0.05957492874321263 requests/s
# <Response [200]>
# Request:58; Frequency: 0.0594883799040863 requests/s
# <Response [200]>
# Request:59; Frequency: 0.05945161967411886 requests/s
# <Response [200]>
# Request:60; Frequency: 0.05931402583521659 requests/s
# <Response [200]>
# Request:61; Frequency: 0.05950348879742444 requests/s
# <Response [200]>
# Request:62; Frequency: 0.05940270082608654 requests/s
# <Response [200]>
# Request:63; Frequency: 0.05962301167667458 requests/s
# <Response [200]>
# Request:64; Frequency: 0.05980151745773643 requests/s
# <Response [200]>
# Request:65; Frequency: 0.05958223982964326 requests/s
# <Response [200]>
# Request:66; Frequency: 0.05981603238457361 requests/s
# <Response [200]>
# Request:67; Frequency: 0.05967921203859335 requests/s
# <Response [200]>
# Request:68; Frequency: 0.05987963025138078 requests/s
# <Response [200]>
# Request:69; Frequency: 0.06009257998103386 requests/s
# <Response [200]>
# Request:70; Frequency: 0.0600714842267058 requests/s
# <Response [200]>
# Request:71; Frequency: 0.06027953356409221 requests/s
# <Response [200]>
# Request:72; Frequency: 0.06027308994943208 requests/s
# <Response [200]>
# Request:73; Frequency: 0.06037646659043733 requests/s
# <Response [200]>
# Request:74; Frequency: 0.060282898201646895 requests/s
# <Response [200]>
# Request:75; Frequency: 0.06041713388760707 requests/s
# <Response [200]>
# Request:76; Frequency: 0.060316577805590584 requests/s
# <Response [200]>
# Request:77; Frequency: 0.06037875228010168 requests/s
# <Response [200]>
# Request:78; Frequency: 0.06026568539738888 requests/s
# <Response [200]>
# Request:79; Frequency: 0.060276396495956626 requests/s
# <Response [200]>
# Request:80; Frequency: 0.06027241063796917 requests/s
# <Response [200]>
# Request:81; Frequency: 0.06045677225705662 requests/s
# <Response [200]>
# Request:82; Frequency: 0.060409289024253784 requests/s
# <Response [200]>
# Request:83; Frequency: 0.060402581078940934 requests/s
# <Response [200]>
# Request:84; Frequency: 0.06059981271096518 requests/s
# <Response [200]>
# Request:85; Frequency: 0.06059425523011798 requests/s
# <Response [200]>
# Request:86; Frequency: 0.0607008605563506 requests/s
# <Response [200]>
# Request:87; Frequency: 0.060770224235567 requests/s
# <Response [200]>
# Request:88; Frequency: 0.06073048241500634 requests/s
# <Response [200]>
# Request:89; Frequency: 0.060749728948439136 requests/s
# <Response [200]>
# Request:90; Frequency: 0.060955298093277974 requests/s
# <Response [200]>
# Request:91; Frequency: 0.06100284235469703 requests/s
# <Response [200]>
# Request:92; Frequency: 0.060947594833692914 requests/s
# <Response [200]>
# Request:93; Frequency: 0.06086243915965999 requests/s
# <Response [200]>
# Request:94; Frequency: 0.060783242548621164 requests/s
# <Response [200]>
# Request:95; Frequency: 0.06077979855373165 requests/s
# <Response [200]>
# Request:96; Frequency: 0.0606739043847455 requests/s
# <Response [200]>
# Request:97; Frequency: 0.060673534450601946 requests/s
# <Response [200]>
# Request:98; Frequency: 0.06076437843183686 requests/s
# <Response [200]>
# Request:99; Frequency: 0.06079300760111458 requests/s
# <Response [200]>
# Request:100; Frequency: 0.060926431872863646 requests/s
# <Response [200]>
# Request:101; Frequency: 0.06091209568508343 requests/s
# <Response [200]>
# Request:102; Frequency: 0.060832362650813786 requests/s
# <Response [200]>
# Request:103; Frequency: 0.06085390791341721 requests/s
# <Response [200]>
# Request:104; Frequency: 0.06096792249534755 requests/s
# <Response [200]>
# Request:105; Frequency: 0.06091279292791881 requests/s
# <Response [200]>
# Request:106; Frequency: 0.06082903749394325 requests/s
# <Response [200]>
# Request:107; Frequency: 0.06090278150744885 requests/s
# <Response [200]>
# Request:108; Frequency: 0.06098155912781321 requests/s
# <Response [200]>
# Request:109; Frequency: 0.06100793911711632 requests/s
# <Response [200]>
# Request:110; Frequency: 0.060993458690762954 requests/s
# <Response [200]>
# Request:111; Frequency: 0.06091800635694861 requests/s
# <Response [200]>
# Request:112; Frequency: 0.060835935543431405 requests/s
# <Response [200]>
# Request:113; Frequency: 0.06089186715632582 requests/s
# <Response [200]>
# Request:114; Frequency: 0.060784546366617495 requests/s
# <Response [200]>
# Request:115; Frequency: 0.060787625111534016 requests/s
# <Response [200]>
# Request:116; Frequency: 0.060822108324928584 requests/s
# <Response [200]>
# Request:117; Frequency: 0.06087913196442689 requests/s
# <Response [200]>
# Request:118; Frequency: 0.06089670065466825 requests/s
# <Response [200]>
# Request:119; Frequency: 0.06094346121922659 requests/s
# <Response [200]>
# Request:120; Frequency: 0.06095418415493602 requests/s
# <Response [200]>
# Request:121; Frequency: 0.06098831335695706 requests/s
# <Response [200]>
# Request:122; Frequency: 0.06096200193628714 requests/s
# <Response [200]>
# Request:123; Frequency: 0.06097485154265853 requests/s
# <Response [200]>
# Request:124; Frequency: 0.06097331165507508 requests/s
# <Response [200]>
# Request:125; Frequency: 0.06088489528108888 requests/s
# <Response [200]>
# Request:126; Frequency: 0.060950642367117794 requests/s
# <Response [200]>
# Request:127; Frequency: 0.06096767358586594 requests/s
# <Response [200]>
# Request:128; Frequency: 0.060919867853564735 requests/s
# <Response [200]>
# Request:129; Frequency: 0.061003118310080845 requests/s
# <Response [200]>
# Request:130; Frequency: 0.06101135838603005 requests/s
# <Response [200]>
# Request:131; Frequency: 0.06093498156899314 requests/s
# <Response [200]>
# Request:132; Frequency: 0.06103670828134661 requests/s
# <Response [200]>
# Request:133; Frequency: 0.06098469072247666 requests/s
# <Response [200]>
# Request:134; Frequency: 0.06094896015144493 requests/s
# <Response [200]>
# Request:135; Frequency: 0.060963026425625635 requests/s
# <Response [200]>
# Request:136; Frequency: 0.06091018925970025 requests/s
# <Response [200]>
# Request:137; Frequency: 0.06104569688936675 requests/s
# <Response [200]>
# Request:138; Frequency: 0.061074628593565286 requests/s
# <Response [200]>
# Request:139; Frequency: 0.06110379350501396 requests/s
# <Response [200]>
# Request:140; Frequency: 0.06118467649436567 requests/s
# <Response [200]>
# Request:141; Frequency: 0.061172939736892064 requests/s
# <Response [200]>
# Request:142; Frequency: 0.0612500602724545 requests/s
# <Response [200]>
# Request:143; Frequency: 0.06125799625237542 requests/s
# <Response [200]>
# Request:144; Frequency: 0.06138208816901597 requests/s
# <Response [200]>
# Request:145; Frequency: 0.06135832199442842 requests/s
# <Response [200]>
# Request:146; Frequency: 0.061436135990286155 requests/s
# <Response [200]>
# Request:147; Frequency: 0.06134685158048649 requests/s
# <Response [200]>
# Request:148; Frequency: 0.06133316616937874 requests/s
# <Response [200]>
# Request:149; Frequency: 0.06128626359695688 requests/s
# <Response [200]>
# Request:150; Frequency: 0.061297985007917596 requests/s
# <Response [200]>
# Request:151; Frequency: 0.06125432929731562 requests/s
# <Response [200]>
# Request:152; Frequency: 0.061193952221223154 requests/s
# <Response [200]>
# Request:153; Frequency: 0.061139700799828674 requests/s
# <Response [200]>
# Request:154; Frequency: 0.06109851671863135 requests/s
# <Response [200]>
# Request:155; Frequency: 0.06108430726989599 requests/s
# <Response [200]>
# Request:156; Frequency: 0.061135686128937695 requests/s
# <Response [200]>
# Request:157; Frequency: 0.06110588783216232 requests/s
# <Response [200]>
# Request:158; Frequency: 0.06104015905114564 requests/s
# <Response [200]>
# Request:159; Frequency: 0.06110223177260099 requests/s
# <Response [200]>
# Request:160; Frequency: 0.061109912478454397 requests/s
# <Response [200]>
# Request:161; Frequency: 0.06108979372355376 requests/s
# <Response [200]>
# Request:162; Frequency: 0.061023080642455124 requests/s
# <Response [200]>
# Request:163; Frequency: 0.06102757390819583 requests/s
# <Response [200]>
# Request:164; Frequency: 0.0610136722892605 requests/s
# <Response [200]>
# Request:165; Frequency: 0.06101420195360153 requests/s
# <Response [200]>
# Request:166; Frequency: 0.06101734324373662 requests/s
# <Response [200]>
# Request:167; Frequency: 0.06100298254770576 requests/s
# <Response [200]>
# Request:168; Frequency: 0.06094888888439609 requests/s
# <Response [200]>
# Request:169; Frequency: 0.0608990144389333 requests/s
# <Response [200]>
# Request:170; Frequency: 0.060861389622117595 requests/s
# <Response [200]>
# Request:171; Frequency: 0.060806698067730654 requests/s
# <Response [200]>
# Request:172; Frequency: 0.0608695988850858 requests/s
# <Response [200]>
# Request:173; Frequency: 0.06084264816515659 requests/s
# <Response [200]>
# Request:174; Frequency: 0.06093786547830994 requests/s
# <Response [200]>
# Request:175; Frequency: 0.060998994992336346 requests/s
# <Response [200]>
# Request:176; Frequency: 0.06103104048941865 requests/s
# <Response [200]>
# Request:177; Frequency: 0.06102190809770004 requests/s
# <Response [200]>
# Request:178; Frequency: 0.061073580993773954 requests/s
# <Response [200]>
# Request:179; Frequency: 0.06105462337779024 requests/s
# <Response [200]>
# Request:180; Frequency: 0.06100129630519595 requests/s
# <Response [200]>
# Request:181; Frequency: 0.06101203491867466 requests/s
# <Response [200]>
# Request:182; Frequency: 0.06111985954233268 requests/s
# <Response [200]>
# Request:183; Frequency: 0.061148171657641616 requests/s
# <Response [200]>
# Request:184; Frequency: 0.061104829784818286 requests/s
# <Response [200]>
# Request:185; Frequency: 0.061065050864154924 requests/s
# <Response [200]>
# Request:186; Frequency: 0.06103119259528569 requests/s
# <Response [200]>
# Request:187; Frequency: 0.06110128070223224 requests/s
# <Response [200]>
# Request:188; Frequency: 0.0611910236602578 requests/s
# <Response [200]>
# Request:189; Frequency: 0.061169631183101605 requests/s
# <Response [200]>
# Request:190; Frequency: 0.06111721631405891 requests/s
# <Response [200]>
# Request:191; Frequency: 0.06114756329329511 requests/s
# <Response [200]>
# Request:192; Frequency: 0.06111542326649627 requests/s
# <Response [200]>
# Request:193; Frequency: 0.06115917072869493 requests/s
# <Response [200]>
# Request:194; Frequency: 0.0611265034945893 requests/s
# <Response [200]>
# Request:195; Frequency: 0.06118163790794187 requests/s
# <Response [200]>
# Request:196; Frequency: 0.06123949355328576 requests/s
# <Response [200]>
# Request:197; Frequency: 0.06121756919968716 requests/s
# <Response [200]>
# Request:198; Frequency: 0.06124133424981971 requests/s
# <Response [200]>
# Request:199; Frequency: 0.06130013850992884 requests/s
# <Response [200]>
# Request:200; Frequency: 0.06132483171152375 requests/s
# <Response [503]>
# Request:201; Frequency: 0.061467237875845196 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 201; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:202; Frequency: 0.06148253817611206 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 202; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:203; Frequency: 0.061622980999570934 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 203; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:204; Frequency: 0.06176794402842745 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 204; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:205; Frequency: 0.061908925943491726 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 205; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:206; Frequency: 0.06193971492761758 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 206; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:207; Frequency: 0.06200677038091169 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 207; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:208; Frequency: 0.06211052479198211 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 208; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:209; Frequency: 0.062215715372979014 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 209; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:210; Frequency: 0.0622642326298336 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 210; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:211; Frequency: 0.06226897540743196 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 211; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:212; Frequency: 0.06235373777347943 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 212; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:213; Frequency: 0.062472399183886036 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 213; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:214; Frequency: 0.06248249525192261 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 214; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:215; Frequency: 0.06262120881237211 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 215; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:216; Frequency: 0.06272103536043601 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 216; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:217; Frequency: 0.06278574053300903 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 217; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:218; Frequency: 0.06292259174989438 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 218; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:219; Frequency: 0.06303814195097858 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 219; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:220; Frequency: 0.06315431268278987 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 220; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:221; Frequency: 0.06318946430050243 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 221; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:222; Frequency: 0.06324903790850231 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 222; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:223; Frequency: 0.06336460478972743 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 223; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# <Response [503]>
# Request:224; Frequency: 0.06342436566707119 requests/s
# C:\Users\ritth\AppData\Local\Temp\ipykernel_46932\4191915401.py:30: UserWarning: Request: 224; Status code: 503
#   warn('Request: {}; Status code: {}'.format(request, response.status_code))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ritth\code\Strive\Streamlit_project\fulldata_for_london_page2.ipynb Cell 78' in <cell line: 7>()
#      <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Streamlit_project/fulldata_for_london_page2.ipynb#ch0000076?line=14'>15</a> response = requests.get(url)
#      <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Streamlit_project/fulldata_for_london_page2.ipynb#ch0000076?line=16'>17</a> # Pause the loop
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Streamlit_project/fulldata_for_london_page2.ipynb#ch0000076?line=17'>18</a> sleep(randint(8,15))
#      <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Streamlit_project/fulldata_for_london_page2.ipynb#ch0000076?line=18'>19</a> print(response)
#      <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Streamlit_project/fulldata_for_london_page2.ipynb#ch0000076?line=19'>20</a> page = BeautifulSoup(response.content, 'html.parser')
#
# KeyboardInterrupt:

# %%
# page2 store in csv, for reuse
soup_p2.to_csv('pub_soup2.csv')

# %%
pub_soup2 = pd.read_csv('C:\\Users\\ritth\\code\\Strive\\Streamlit_project\\pub_soup2.csv').drop(columns='Unnamed: 0').squeeze()

# %% [markdown]
# ### Name

# %%
name = []
for row in pub_soup:  
    result = row.select('.css-1egxyvc .css-1m051bw') 
    for tag in result:
        #print(tag.text)
        name.append(tag.text)

# %%
#pd.Series(name).value_counts()

# %% [markdown]
# ### Ratings

# %%
rating = []
container_class = 'container__09f24__mpR8_ hoverable__09f24__wQ_on margin-t3__09f24__riq4X margin-b3__09f24__l9v5d padding-t3__09f24__TMrIW padding-r3__09f24__eaF7p padding-b3__09f24__S8R2d padding-l3__09f24__IOjKY border--top__09f24__exYYb border--right__09f24__X7Tln border--bottom__09f24___mg5X border--left__09f24__DMOkM border-color--default__09f24__NPAKY'
for row in pub_soup:
    result = row.find_all(class_ = container_class)

    for tag in result:
        header_text = tag.div.div.div.nextSibling.div
        rat = header_text.select_one('.overflow--hidden__09f24___ayzG')
        if rat is not None:
            rating.append(rat['aria-label'].split()[0])
        else:
            rating.append(np.nan)

# %%
# test
# for n, rat in zip(name, rating):
#     print(n, rat)

# %% [markdown]
# ### Reviews

# %%
reviews = []
container_class = 'container__09f24__mpR8_ hoverable__09f24__wQ_on margin-t3__09f24__riq4X margin-b3__09f24__l9v5d padding-t3__09f24__TMrIW padding-r3__09f24__eaF7p padding-b3__09f24__S8R2d padding-l3__09f24__IOjKY border--top__09f24__exYYb border--right__09f24__X7Tln border--bottom__09f24___mg5X border--left__09f24__DMOkM border-color--default__09f24__NPAKY'
for row in pub_soup:
    result = row.find_all(class_ = container_class)

    for tag in result:
        header_text = tag.div.div.div.nextSibling.div
        rev = header_text.select_one('.reviewCount__09f24__tnBk4')
        if rev is not None:
            reviews.append(rev.text)
        else:
            reviews.append(np.nan)

# %%
# test
# for n, rev in zip(name, reviews):
#     print(n, rev)

# %% [markdown]
# ### Price

# %%
price_range = []
container_class = 'container__09f24__mpR8_ hoverable__09f24__wQ_on margin-t3__09f24__riq4X margin-b3__09f24__l9v5d padding-t3__09f24__TMrIW padding-r3__09f24__eaF7p padding-b3__09f24__S8R2d padding-l3__09f24__IOjKY border--top__09f24__exYYb border--right__09f24__X7Tln border--bottom__09f24___mg5X border--left__09f24__DMOkM border-color--default__09f24__NPAKY'
for row in pub_soup:
    result = row.find_all(class_ = container_class)

    for tag in result:
        header_text = tag.div.div.div.nextSibling.div
        price = header_text.select_one('.css-1s7bx9e')
        if price is not None:
            price_range.append(price.text)
        else:
            price_range.append(np.nan)

# %%
# test
# for n, price in zip(name, price_range):
#     print(n, price)

# %% [markdown]
# ### Location

# %%
location = [] 
for row in pub_soup2:
    soup = BeautifulSoup(row, 'html.parser')
    result = soup.select('address .raw__09f24__T4Ezm')

    adress_elements = []
    for tag in result:
        adress_elements.append(tag.text)
    location.append( '--'.join(adress_elements) )

# %%
location
# Out:
# ['47 Chandos Place--London WC2N 4HS--United Kingdom',
#  '13 Westmoreland Street--London W1G 8PJ--United Kingdom',
#  '6 New Quebec Street--London W1H 7RQ--United Kingdom',
#  '15 Denman Street--London W1D 7HN--United Kingdom',
#  '11 Warwick Way--Pimlico--London SW1V 1QT--United Kingdom',
#  '66 Bayswater Road--London W2 3PH--United Kingdom',
#  '',
#  '30 Southwick Street--London W2 1JQ--United Kingdom',
#  '5 Bruton Street--London W1J 6PT--United Kingdom',
#  '13 Kingly Court--Carnaby Street--Soho W1B 5PW--United Kingdom',
#  '95 Chancery Lane--London WC2A 1DT--United Kingdom',
#  '12 Seymour Place--London W1H 7NE--United Kingdom',
#  '29 Ordnance Hill--London NW8 6PS--United Kingdom',
#  '18 Bateman Street--London W1D 3AJ--United Kingdom',
#  '26 Ganton Street--London W1F 7QZ--United Kingdom',
#  '119 Kensington Church Street--London W8 7LN--United Kingdom',
#  '145 Fleet Street--London EC4A 2BU--United Kingdom',
#  "23 Crown Passage--St James's--London SW1Y 6PP--United Kingdom",
#  '21 Poland Street--Soho W1F 8QG--United Kingdom',
#  '209 Earls Ct Road--London SW5 9AN--United Kingdom',
#  '40 Great Queen Street--Covent Garden--London WC2B 5AA--United Kingdom',
#  '27 Walham Grove--Fulham--London SW6 1QP--United Kingdom',
#  '39-45 Shaftesbury Avenue--London W1D 6LA--United Kingdom',
#  '72 Grafton Way--London--London W1T 5DU--United Kingdom',
#  '14-16 Rupert Street--London W1D 6DD--United Kingdom',
#  '243 Union Street--London SE1 0LR--United Kingdom',
#  '80 Liverpool Road--London N1 0QD--United Kingdom',
#  '23 Francis Street--London SW1P 1DN--United Kingdom',
#  '29 Passmore Street--London SW1W 8HR--United Kingdom',
#  '10 Berners Street--London W1T 3NP--United Kingdom',
#  '17 Needham Road--London W11 2RP--United Kingdom',
#  'The Connaught--Carlos Place--Mayfair--London W1K 2AL--United Kingdom',
#  '11 Langley Street--London WC2H 9JG--United Kingdom',
#  '1A Bedford St--London WC2E 9HH--United Kingdom',
#  '93 Marylebone High Street--London W1U 4RE--United Kingdom',
#  '5 North Wharf Road--Paddington--London W2 1LA--United Kingdom',
#  '82 Duke Street--London W1K 6JF--United Kingdom',
#  '24 Aberdeen Place--London NW8 8JR--United Kingdom',
#  "30 Queen's Gate Mews--Kensington--London SW7 5QL--United Kingdom",
#  '19 Carlisle Street--London W1D 3BY--United Kingdom',
#  '18 Wilton Row--Belgravia--London SW1X 7NR--United Kingdom',
#  '6 Old Court Place--Kensington Church Street--London W8 4PL--United Kingdom',
#  '66 Wigmore St--London W1U 2SB--United Kingdom',
#  '1 Ely Court--Ely Place--London EC1N 6SJ--United Kingdom',
#  '28 Horselydown Lane--London SE1 2LN--United Kingdom',
#  '2 Shepherd Market--London W1J 7QA--United Kingdom',
#  '37 Great Windmill Street--Soho--London W1D 7LT--United Kingdom',
#  '26-27 Great Tower Street--London EC3R 5AQ--United Kingdom',
#  '88 Marylebone Lane--Marylebone--London W1U 2PY--United Kingdom',
#  '168 High Holborn--London WC1V 7AA--United Kingdom',
#  '2-3 Greenland Place--London NW1 0AP--United Kingdom',
#  '5 Charles Street--London W1J 5DF--United Kingdom',
#  '51 Upper Berkeley Street--London W1H 7QW--United Kingdom',
#  '30 Portman Square--London W1H 7BH--United Kingdom',
#  "7 St Andrew's Hill--London EC4V 5BY--United Kingdom",
#  '33 Rose Street--Covent Garden--London WC2E 9EB--United Kingdom',
#  '50 Davies Street--Mayfair--London W1K 5JE--United Kingdom',
#  '57 Wapping Wall--London E1W 3SH--United Kingdom',
#  '17 Hogarth Place--London SW5 0QT--United Kingdom',
#  '138-139 Shoreditch High Street--Shoreditch--London E1 6JE--United Kingdom',
#  '6-8 Mill Street--London W1S 2AZ--United Kingdom',
#  '27 Great Portland Street--London W1W 8QE--United Kingdom',
#  '1 Randolph Street--London NW1 0SS--United Kingdom',
#  '141 Albert Street--London NW1 7NB--United Kingdom',
#  '42 Wellington Street--London WC2E 7BD--United Kingdom',
#  '126 Crawford Street--London W1U 6BF--United Kingdom',
#  '23 Poland Street--London W1F 8QJ--United Kingdom',
#  '22 Park Lane--London W1K 1BE--United Kingdom',
#  'The Lanesborough--Lanesborough Place--London SW1X 7TA--United Kingdom',
#  '38 Old Town--Clapham--London SW4 0LB--United Kingdom',
#  '2 Castlehaven Road--London NW1 8QU--United Kingdom',
#  '174 Queen Victoria Street--London EC4V 4EG--United Kingdom',
#  '140 Park Lane--London W1K 7AA--United Kingdom',
#  '5 Little Portland Street--London W1W 7JD--United Kingdom',
#  'Grosvenor Square--London W1K 6JP--United Kingdom',
#  '109 Praed Street--London W2 1RL--United Kingdom',
#  '21 London Street--London W2 1HL--United Kingdom',
#  '5-6 Leicester Square--London WC2H 7NA--United Kingdom',
#  'Coram Street--Bloomsbury--London WC1N 1HT--United Kingdom',
#  '22 Chalcot Road--London NW1 8LL--United Kingdom',
#  '41 Farm Street--Mayfair W1J 5RP--United Kingdom',
#  '35 New Cavendish Street--Marylebone W1G 9TR--United Kingdom',
#  '28 Chilworth Street--Paddington--London W2 6DT--United Kingdom',
#  '33-37 Wardour Street--Soho--London W1D 6PU--United Kingdom',
#  '45 Dean Street--London W1D 4QB--United Kingdom',
#  '174 Camden High Street--London NW1 0NE--United Kingdom',
#  '45 Harrowby st--London W1H 5HT--United Kingdom',
#  '53 Kinnerton Street--London SW1X 8ED--United Kingdom',
#  '7 Shepherd Street--London W1J 7HR--United Kingdom',
#  '6 Charlwood Street--London SW1V 2EE--United Kingdom',
#  '224 Camden High Street--London NW1 8QR--United Kingdom',
#  '110 Bishopsgate--40th Floor--London EC2N 4AY--United Kingdom',
#  '51 Upper Berkeley Street--Marylebone--London W1H 7QW--United Kingdom',
#  '15 Langham Place--London W1B 3DE--United Kingdom',
#  '111 Long Lane--London SE1 4PH--United Kingdom',
#  '34 Holland Road--London W14 8BA--United Kingdom',
#  '64 Brewer Street--London W1F 9TP--United Kingdom',
#  '76 Narrow Street--London E14 8BP--United Kingdom',
#  '45 Jermyn Street--London SW1Y 6JD--United Kingdom',
#  '13 Edgware Road--London W2 2JE--United Kingdom',
#  '14 Kingly Street--London W1B 5PP--United Kingdom',
#  '372 Kennington Lane--London SE11 5HY--United Kingdom',
#  '14 Belgrave Road--London SW1V 1QD--United Kingdom',
#  '12 Gate Street--Holborn--London WC2A 3HP--United Kingdom',
#  '11 Avery Row--Mayfair--London W1K 4AN--United Kingdom',
#  '35 Maiden Lane--London WC2E 7LB--United Kingdom',
#  'Alphabeta Building--2A Worship Street--London EC2A 2AH--United Kingdom',
#  '55-57 Northdown Street--London N1 9BL--United Kingdom',
#  '1 - 5 West Street--London WC2H 9NQ--United Kingdom',
#  '127 Gloucester Road--London SW7 4TE--United Kingdom',
#  '43-47 Marylebone Road--London NW1 5JY--United Kingdom',
#  '29 Greek Street--London W1D 5DH--United Kingdom',
#  '17 Manette Street--London W1D 4AS--United Kingdom',
#  '222 Marylebone Road--London NW1 6JQ--United Kingdom',
#  '48 Chapel Street--London NW1 5DP--United Kingdom',
#  'The Park Lane Hotel--Piccadilly--London W1J 7BX--United Kingdom',
#  '112 Vauxhall Walk--London SE11 5ER--United Kingdom',
#  '28 Rathbone Place--London W1T 1JF--United Kingdom',
#  '35 Chalk Farm Road--London NW1 8AJ--United Kingdom',
#  '160 Picadilly--London W1J 9EB--United Kingdom',
#  '32 Caledonian Road--London N1 9DT--United Kingdom',
#  "Gabriel's Wharf--56 Upper Ground--London SE1 9PP--United Kingdom",
#  '66 Acton Street--London WC1X 9NB--United Kingdom',
#  '217 Uxbridge Road--Shepherds Bush--London W12 9DH--United Kingdom',
#  '17 Leinster Terrace--London W2 3EU--United Kingdom',
#  '55 Orsman Road--London N1 5RA--United Kingdom',
#  '1 Kensington Square--London W8 5EP--United Kingdom',
#  '117 Rotherhithe Street--London SE16 4NF--United Kingdom',
#  '10 Motcomb Street--London SW1X 8LA--United Kingdom',
#  '15 Clifton Road--Maida Vale--London W9 1SY--United Kingdom',
#  '77 Wardour Street--London W1D 6QA--United Kingdom',
#  '92-94 Lambs Conduit Street--London WC1N 3LZ--United Kingdom',
#  '3A Kensington High Street--Kensington--London W8 5NP--United Kingdom',
#  '100 Upper Street--London N1 0NP--United Kingdom',
#  '10-11 Northumberland Street--London WC2N 5DB--United Kingdom',
#  '61 Poland Street--London W1F 7NU--United Kingdom',
#  '208 High Holborn--London WC1V 7BW--United Kingdom',
#  '133 Westminster Bridge Road--London SE1 7HR--United Kingdom',
#  '7A Stanhope Street--London NW1 3RD--United Kingdom',
#  '87 Flood Street--London SW3 5TB--United Kingdom',
#  '16 Charlotte Street--London W1T 2NA--United Kingdom',
#  '171 Portobello Road--London W11 2DY--United Kingdom',
#  '42 St Pancras Way--London NW1 0QT--United Kingdom',
#  '75-77 Borough High Street--London SE1 1NH--United Kingdom',
#  '97 Haverstock Hill--London NW3 4RL--United Kingdom',
#  '49 Great Russell Street--Bloomsbury WC1B 3BA--United Kingdom',
#  '113 Bayham Street--Camden Town--London NW1 0AG--United Kingdom',
#  '1st Floor--Paddington Station--London W2 1HB--United Kingdom',
#  '15 Selwood Terrace--London SW7 3QG--United Kingdom',
#  '124 Kentish Town Road--London NW1 9QB--United Kingdom',
#  '4 Dover Street--London W1S 4LB--United Kingdom',
#  '187 Rye Lane--London SE15 4TP--United Kingdom',
#  '97 Gloucester Road--London SW7 4SS--United Kingdom',
#  '148B Old Park Lane--London--London W1K 1QY--United Kingdom',
#  '47 Rathbone Street--London W1T 1NW--United Kingdom',
#  '23a Edwardes Square--London W8 6HE--United Kingdom',
#  '',
#  '77 Castle Road--Camden Town--London NW1 8SU--United Kingdom',
#  '98 Finchley Road--London NW3 5EL--United Kingdom',
#  "310c Earl's Court Road--London SW5 9BA--United Kingdom",
#  '86 Queensway--London W2 3RR--United Kingdom',
#  '96 Clifton Hill--London NW8 0JT--United Kingdom',
#  '94 Parkway--London NW1 7AN--United Kingdom',
#  '47 Villiers Street--London WC2N 6NE--United Kingdom',
#  '59 Marylebone Lane--London W1U 2NY--United Kingdom',
#  '50 Hertford Street--London W1J 7SS--United Kingdom',
#  '1 Portman Mews S--Marylebone W1H 6HR--United Kingdom',
#  'Spaniards Road--London NW3 7JJ--United Kingdom',
#  '75 Page Street--Westminster--London SW1P 4LT--United Kingdom',
#  '104 Finchley Road--London NW3 5JJ--United Kingdom',
#  '35 Old Church Street--Chelsea--London SW3 5BS--United Kingdom',
#  '58 Poland Street--London W1F 7NR--United Kingdom',
#  '28 Holywell Row--London EC2A 4JB--United Kingdom',
#  '373 Commercial Road--Stepney--London E1 0LA--United Kingdom',
#  '73 Cheshire Street--London E2 6EG--United Kingdom',
#  '18 Argyll Street--London W1D 2--United Kingdom',
#  '36 Drury Lane--London WC2B 5RR--United Kingdom',
#  '1-3 Warwick Street--London W1B 5LR--United Kingdom',
#  '38 Connaught Street--London W2 2AF--United Kingdom',
#  "37 Wharfdale Road--King's Cross--London N1 9SD--United Kingdom",
#  '13 Eyre Street Hill--London EC1R 5ET--United Kingdom',
#  '11 London Street--London W2 1HL--United Kingdom',
#  '175 Westbourne Grove--London W11 2SB--United Kingdom',
#  '22 Frith Street--London W1D 4RP--United Kingdom',
#  '172 Westminster Bridge Road--London SE1 7RW--United Kingdom',
#  '69 Rosebery Avenue--London EC1R 4RL--United Kingdom',
#  '108A Tottenham Court Road--London W1T 5AA--United Kingdom',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %% [markdown]
# ### Photos

# %%
nb_photos = []
photo_header_class = 'photo-header-content-container__09f24__jDLBB border-color--default__09f24__NPAKY'
for row in pub_soup2:
    soup = BeautifulSoup(row, 'html.parser')
    photo_header = soup.find(class_ = photo_header_class)

    if photo_header is not None:
        nb_photos.append(  pd.Series(photo_header.text).str.extract(r'See (\d+) photos').squeeze()  )
    else:
        nb_photos.append(np.nan)

# %%
# df numbers of photo
for name, photo in zip(pub_soup2.index, nb_photos):
    print(name, photo)

# %% [markdown]
# # Dataframe

# %%
pub_df = pd.DataFrame({'Name':name, 'Rating':rating, 'Reviews': reviews, 'Price Range in £': price_range, 'Number of Photos': nb_photos, 'Location': location})

# %%
# store data
pub_df.to_csv('pubs_data.csv', index=False)

# %%
#pub_df.head()

# %%
#pub_df.info()

# %% [markdown]
# ### Changing price value

# %%
# 1 pound = 1.31 USD
Euro = (pd.Series([10, 11, 30, 31, 60, 61]) * 1.31).apply(lambda x: int(x))
#print(Euro)
mapper = {'£':'under 13', '££':'[14 - 39]', '£££':'[40 - 78]', '££££':'over 79'}
pub_df['Price Range'] = pub_df['Price Range'].map(mapper)

# %%
# Top 20 Most reviews

#pub_df.sort_values(by='Reviews', ascending=False).head(20)
